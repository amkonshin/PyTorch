# %% [markdown]
# # GAN (Generative Adversarial Network)
# ## Генеративно-состязательная нейросеть

# %% [markdown]
# Сегодня мы поговорим о генеративно-состязательных нейросетях. Они же:
# * генеративные соревновательные сети
# * порождающие соперничающие сети
# * порождающие соревнующиеся сети

# %% [markdown]
# #### Примеры работы GAN:
# * https://www.thispersondoesnotexist.com/ - генерация несуществующих лиц
# * https://thiscatdoesnotexist.com/ - генерация несуществующих котов (ошибки в генерации котов: https://aiweirdness.com/post/182633984547/gancats)
# * https://www.youtube.com/watch?v=PCBTZh41Ris - генерация танцевальных движений

# %% [markdown]
# #### Генеративно-состязательная сеть (англ. Generative adversarial network)
# — алгоритм машинного обучения без учителя, построенный на комбинации из двух нейронных сетей, одна из которых (сеть $G$, генератор) генерирует образцы，а другая (сеть $D$, дискриминатор) старается отличить правильные («подлинные») образцы от неправильных. https://ru.wikipedia.org/wiki/%D0%93%D0%B5%D0%BD%D0%B5%D1%80%D0%B0%D1%82%D0%B8%D0%B2%D0%BD%D0%BE-%D1%81%D0%BE%D1%81%D1%82%D1%8F%D0%B7%D0%B0%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D0%B0%D1%8F_%D1%81%D0%B5%D1%82%D1%8C

# %% [markdown]
# Если совсем коротко, то:

# %% [markdown]
# $$\min _{G} \max _{D} V(D, G)=\mathbb{E}_{\boldsymbol{x} \sim p_{\text {data }}(\boldsymbol{x})}[\log D(\boldsymbol{x})]+\mathbb{E}_{\boldsymbol{z} \sim p_{\boldsymbol{z}}(\boldsymbol{z})}[\log (1-D(G(\boldsymbol{z})))]$$

# %% [markdown]
# Где:
# * $x$ - реальные данные из обучающй выборки
# * $D(x)$ - результат работы дискриминатора, т.е. вероятность того, что перед нами несгенерированные данные
# * $z$ - случайный вектор фиксированной длины, выбранный из нормального распределения
# * $G(z)$ - сгенерированные из $z$ данные
#
# Задача для $G$ - генерировать данные $p_g$ с таким же распределением как и у реальных данных  $p_{data}$ .
# Цель $D$ же - отличать сгенерированные данные от оригиналов.
# Тогда $D(G(z))$ - вероятность того, что данные из генератора являются реальными. Идеальный результат обучения GAN - $p_{data} = p_g$

# %% [markdown]
# ### Дискриминатор ($D$)

# %% [markdown]
# Модель дискриминатора берет входные данные (реальные или сгенерированный) и предсказывает к какому из этих двух классов принадлежат эти данные.
# Обучение сводится к минимизация функции потерь.
#
# После процесса обучения модель дискриминатора отбрасывается, поскольку нас уже интересует только генерация данных.

# %% [markdown]
# ### Генератор ($G$)

# %% [markdown]
# Задача генератора - создавать «поддельные» изображения, похожие на те, что в обучающей выборке.
# Во время обучения генератор постоянно пытается обыграть дискриминатор, улучшая качество подделок.

# %% [markdown]
# ### Vanilla GAN

# %% [markdown]
# Рассмотрим реализацю самой первой статьи по GAN'ам на классическом датасете MNIST
#
# Generative Adversarial Nets Ian J. Goodfellow (2014) https://papers.nips.cc/paper/5423-generative-adversarial-nets.pdf

# %% [markdown]
# ![GANs_%D1%81%D1%85%D0%B5%D0%BC%D0%B0.png](attachment:GANs_%D1%81%D1%85%D0%B5%D0%BC%D0%B0.png)

# %% [markdown]
# Подключаем нужные модули и библиотеки

# %%
import os
import numpy as np
import math

from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torchvision import datasets
from torch.autograd import Variable

import torch.nn as nn
import torch

########### Вывод изображений и сохранение ################################
import matplotlib.pyplot as plt
from IPython import display
from torchvision.utils import save_image, make_grid

# %%
# %%time
# Out:
# UsageError: %%time is a cell magic, but the cell body is empty. Did you mean the line magic %time (single %)?

# %%
use_cuda = torch.cuda.is_available()
# device = torch.device("cpu")
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)

# %%
######## функция для вывода и сохранения изображения ########
def sample_image(static_sample, save_img = False):
    npimg = make_grid(static_sample.data[:25]).cpu().numpy()
    fig, ax = plt.subplots(figsize=(7, 7))
    ax.imshow(np.transpose(npimg, (1,2,0)), interpolation="nearest")
    if save_img:
        save_image(gen_imgs.data[:25], "images/%d.png" % batches_done, nrow=5, normalize=True)

# %% [markdown]
# Параметры для обучения обеих моделей

# %%
n_epochs = 200
batch_size = 64
lr = 0.0002

b1 = 0.5
b2 = 0.999

latent_dim = 100

n_classes = 10
img_size = 28
channels = 1

sample_interval = 25

img_shape = (channels, img_size, img_size)

# %% [markdown]
# Генератор

# %%
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        
        def block(in_feat, out_feat, normalize=True): #activation='relu
            layers = [nn.Linear(in_feat, out_feat)]
            if normalize:
                layers.append(nn.BatchNorm1d(out_feat, 0.8))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        self.model = nn.Sequential(
            *block(latent_dim, 128, normalize=False),
            *block(128, 256),
            *block(256, 512),
            *block(512, 1024),
            nn.Linear(1024, int(np.prod(img_shape))),
            nn.Tanh()
        )
#         self.activations = nn.ModuleDict([
#                 ['lrelu', nn.LeakyReLU()],
#                 ['relu', nn.ReLU()]])

    def forward(self, z):
        img = self.model(z)
        img = img.view(img.size(0), *img_shape)
        return img

# %% [markdown]
# #### ... Небольшое отступление
# Создание своих слоев

# %%
class CustomLinearLayer(nn.Module):
    def __init__(self, size_in, size_out):
        super().__init__()
        self.size_in, self.size_out = size_in, size_out
        
        weights = torch.Tensor(size_out, size_in)
        self.weights = nn.Parameter(weights) 

        bias = torch.Tensor(size_out)
        self.bias = nn.Parameter(bias)

        nn.init.uniform_(self.weights, -0.005, 0.005) 
        nn.init.uniform_(self.bias, -0.005, 0.005)  

    def forward(self, x):
        w_times_x = torch.mm(x, self.weights.t())
        return torch.add(w_times_x, self.bias)

# %% [markdown]
# #### nn.init
# https://pytorch.org/docs/stable/nn.init.html

# %% [markdown]
# Дискриминатор

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()

        self.model = nn.Sequential(
            CustomLinearLayer(int(np.prod(img_shape)), 512),
            nn.LeakyReLU(0.2, inplace=True),
            CustomLinearLayer(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            CustomLinearLayer(256, 1),
            nn.Sigmoid(),
        )
  

    def forward(self, img):
        img_flat = img.view(img.size(0), -1)
        validity = self.model(img_flat)

        return validity

# %% [markdown]
# Загрузка датасета

# %%
real_data = torch.utils.data.DataLoader(
    datasets.MNIST(
        "../../data/mnist",
        train=True,
        download=True,
        transform=transforms.Compose(
            [transforms.Resize(img_size), transforms.ToTensor(), transforms.Normalize([0.5], [0.5])]
        ),
    ),
    batch_size=batch_size,
    shuffle=True,
)

# %%
dataiter = iter(real_data)
images, labels = dataiter.next()
images = images.numpy()

img = np.squeeze(images[0])
img1 = np.squeeze(images[1])
img2 = np.squeeze(images[2])

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (12,4))
ax1.imshow(img, cmap='gray')
ax2.imshow(img1, cmap='gray')
ax3.imshow(img2, cmap='gray')

# %% [markdown]
# Инициализация

# %%
generator = Generator().to(device)
discriminator = Discriminator().to(device)


optimizer_G = torch.optim.Adam(generator.parameters(), lr=lr, betas=(b1, b2))
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(b1, b2))

adversarial_loss = torch.nn.BCELoss()

# %%
d_loss_history = []
g_loss_history = []

# %%
import matplotlib.patches as mpatches

red_patch = mpatches.Patch(color='red', label='D loss')
green_patch = mpatches.Patch(color='green', label='G loss')



for epoch in range(n_epochs):
    for i, (imgs, labels) in enumerate(real_data):

        batch_size = imgs.shape[0]
##################### Лейблы для данных: 1 - настоящие, 0 - сгенерированные ########
        valid = Variable(torch.FloatTensor(batch_size, 1).fill_(1.0), requires_grad=False).to(device)
        fake = Variable(torch.FloatTensor(batch_size, 1).fill_(0.0), requires_grad=False).to(device)

        real_imgs = Variable(imgs.type(torch.FloatTensor)).to(device)


######################  Тренировка генератора    ##########################

        optimizer_G.zero_grad()
    
        #генерация шума
        z = Variable(torch.FloatTensor(np.random.normal(0, 1, (batch_size, latent_dim)))).to(device)

        gen_imgs = generator(z)

        validity = discriminator(gen_imgs)
        g_loss = adversarial_loss(validity, valid)
        
        g_loss.backward()
        optimizer_G.step()

######################  Тренировка дискриминатора    ##########################

        optimizer_D.zero_grad()

        real_pred = discriminator(real_imgs)
        d_real_loss = adversarial_loss(real_pred, valid)

        fake_pred = discriminator(gen_imgs.detach())
        d_fake_loss = adversarial_loss(fake_pred, fake)

        d_loss = (d_real_loss + d_fake_loss) / 2

        d_loss.backward()
        optimizer_D.step()
        
######## Отображение процесса обучения и вывод функций потерь ############
        batches_done = epoch * len(real_data) + i
    
        if batches_done % sample_interval == 0:
            plt.clf()
            
            display.clear_output(wait=False)
            sample_image(gen_imgs)
            print("[Epoch %d/%d] [Batch %d/%d] [D loss: %f] [G loss: %f]"% (epoch, n_epochs, i, len(real_data), d_loss.item(), g_loss.item()) ) 

            
            display.display(plt.gcf())

#             d_loss_history.append(d_loss)
#             g_loss_history.append(g_loss)

#             plt.plot(np.log(np.array(d_loss_history)), label='D loss', color = 'red')
#             plt.plot(np.log(np.array(g_loss_history)), label='G loss', color = 'green')
#             plt.legend(handles=[red_patch, green_patch])
#             plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [Epoch 18/200] [Batch 916/938] [D loss: 0.319099] [G loss: 2.669308]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-eae3e3a2b3ec> in <module>
#       7
#       8 for epoch in range(n_epochs):
# ----> 9     for i, (imgs, labels) in enumerate(real_data):
#      10
#      11         batch_size = imgs.shape[0]
#
# ~/.local/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/.local/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# ~/.local/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/.local/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/.local/lib/python3.7/site-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#      95
#      96         if self.transform is not None:
# ---> 97             img = self.transform(img)
#      98
#      99         if self.target_transform is not None:
#
# ~/.local/lib/python3.7/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      68     def __call__(self, img):
#      69         for t in self.transforms:
# ---> 70             img = t(img)
#      71         return img
#      72
#
# ~/.local/lib/python3.7/site-packages/torchvision/transforms/transforms.py in __call__(self, tensor)
#     173             Tensor: Normalized Tensor image.
#     174         """
# --> 175         return F.normalize(tensor, self.mean, self.std, self.inplace)
#     176
#     177     def __repr__(self):
#
# ~/.local/lib/python3.7/site-packages/torchvision/transforms/functional.py in normalize(tensor, mean, std, inplace)
#     216     mean = torch.as_tensor(mean, dtype=dtype, device=tensor.device)
#     217     std = torch.as_tensor(std, dtype=dtype, device=tensor.device)
# --> 218     tensor.sub_(mean[:, None, None]).div_(std[:, None, None])
#     219     return tensor
#     220
#
# KeyboardInterrupt:

# %% [markdown]
# Анимация первых 88 эпох обучения

# %% [markdown]
# ![myimage.gif](attachment:myimage.gif)

# %%
torch.save(generator.state_dict(), "vanilla_gan.pth")

# %% [markdown]
# https://medium.com/@jonathan_hui

# %% [markdown]
# Домашнее задание:
#
# 1. Как было сказано ранее, GAN обучается воспроизводить реальные данные. Поэтому Вам предлагается обучить генератор создавать точки, которые будут лежать на графике функции $y = \frac{sin(x)}{x} - \frac{x}{10}$. При выполненинии данного задания структура GAN остается той же, но Вам нужно:
#  * Сгенерировать настоящие данные
#  * Изменить архитектуру дискриминатора и генератора
#  * Без графиков домашку не принимаю
#
#
# 2. Изменить используемые модели генератора и дискриминатора, с помощью сверточных слоев. Идея: https://arxiv.org/abs/1511.06434 Датасет можно использовать так же MNIST.

# %%
x = np.linspace(1,30,2)
def func_y(x):
    return np.sin(x)/x - x/10
print("Func_y:", func_y(x))
# Out:
# Func_y: [ 0.74147098 -3.03293439]

# %%
train_data_length = 512
train_data = torch.zeros((train_data_length, 2))
train_data[:, 0] = 2 * math.pi * torch.rand(train_data_length)
train_data[:, 1] = func_y(train_data[:, 0])
train_labels = torch.zeros(train_data_length)
train_set = [
    (train_data[i], train_labels[i]) for i in range(train_data_length)]

# %%
batch_size = 16
train_loader = torch.utils.data.DataLoader(
    train_set, batch_size=batch_size, shuffle=True)

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()

        self.model = nn.Sequential(
            nn.Linear(2, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid(),
        )
  

    def forward(self, x):
        output = self.model(x)
        

        return output

# %%
discriminator = Discriminator()

# %%
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(2, 16),
            nn.ReLU(),
            nn.Linear(16, 32),
            nn.ReLU(),
            nn.Linear(32, 2))

    def forward(self, x):
        output = self.model(x)
        return output

# %%
generator = Generator()

# %%
lr = 0.001
num_epochs = 300
loss_function = nn.BCELoss()

# %%
optimizer_discriminator = torch.optim.Adam(discriminator.parameters(), lr=lr)
optimizer_generator = torch.optim.Adam(generator.parameters(), lr=lr)

# %%
for epoch in range(num_epochs):
    for n, (real_samples, _) in enumerate(train_loader):
        # Данные для обучения дискриминатора
        real_samples_labels = torch.ones((batch_size, 1))
        latent_space_samples = torch.randn((batch_size, 2))
        generated_samples = generator(latent_space_samples)
        generated_samples_labels = torch.zeros((batch_size, 1))
        all_samples = torch.cat((real_samples, generated_samples))
        all_samples_labels = torch.cat(
            (real_samples_labels, generated_samples_labels))

        # Обучение дискриминатора
        discriminator.zero_grad()
        output_discriminator = discriminator(all_samples)
        loss_discriminator = loss_function(
            output_discriminator, all_samples_labels)
        loss_discriminator.backward()
        optimizer_discriminator.step()

        # Данные для обучения генератора
        latent_space_samples = torch.randn((batch_size, 2))

        # Обучение генератора
        generator.zero_grad()
        generated_samples = generator(latent_space_samples)
        output_discriminator_generated = discriminator(generated_samples)
        loss_generator = loss_function(
            output_discriminator_generated, real_samples_labels)
        loss_generator.backward()
        optimizer_generator.step()

        # Выводим значения функций потерь
        if epoch % 10 == 0 and n == batch_size - 1:
            print(f"Epoch: {epoch} Loss D.: {loss_discriminator}")
            print(f"Epoch: {epoch} Loss G.: {loss_generator}")
# Out:
# Epoch: 0 Loss D.: 0.70412677526474
# Epoch: 0 Loss G.: 0.6479371786117554
# Epoch: 10 Loss D.: 0.7102339863777161
# Epoch: 10 Loss G.: 0.7077499628067017
# Epoch: 20 Loss D.: 0.67521733045578
# Epoch: 20 Loss G.: 0.7999065518379211
# Epoch: 30 Loss D.: 0.6823394298553467
# Epoch: 30 Loss G.: 0.6981488466262817
# Epoch: 40 Loss D.: 0.6955453157424927
# Epoch: 40 Loss G.: 0.7264102697372437
# Epoch: 50 Loss D.: 0.6943596005439758
# Epoch: 50 Loss G.: 0.6791555881500244
# Epoch: 60 Loss D.: 0.6930822134017944
# Epoch: 60 Loss G.: 0.6851394176483154
# Epoch: 70 Loss D.: 0.6870280504226685
# Epoch: 70 Loss G.: 0.7148464322090149
# Epoch: 80 Loss D.: 0.6840909719467163
# Epoch: 80 Loss G.: 0.7117919921875
# Epoch: 90 Loss D.: 0.6787430644035339
# Epoch: 90 Loss G.: 0.6844430565834045
# Epoch: 100 Loss D.: 0.6948435306549072
# Epoch: 100 Loss G.: 0.6997455954551697
# Epoch: 110 Loss D.: 0.6884331107139587
# Epoch: 110 Loss G.: 0.7099593281745911
# Epoch: 120 Loss D.: 0.6928345561027527
# Epoch: 120 Loss G.: 0.6931604743003845
# Epoch: 130 Loss D.: 0.6959999203681946
# Epoch: 130 Loss G.: 0.6930588483810425
# Epoch: 140 Loss D.: 0.693966805934906
# Epoch: 140 Loss G.: 0.706838846206665
# Epoch: 150 Loss D.: 0.6990864872932434
# Epoch: 150 Loss G.: 0.6903292536735535
# Epoch: 160 Loss D.: 0.6952386498451233
# Epoch: 160 Loss G.: 0.6919607520103455
# Epoch: 170 Loss D.: 0.6929748058319092
# Epoch: 170 Loss G.: 0.6800123453140259
# Epoch: 180 Loss D.: 0.6937735676765442
# Epoch: 180 Loss G.: 0.6982263326644897
# Epoch: 190 Loss D.: 0.6945616602897644
# Epoch: 190 Loss G.: 0.6911331415176392
# Epoch: 200 Loss D.: 0.6817260980606079
# Epoch: 200 Loss G.: 0.7074292898178101
# Epoch: 210 Loss D.: 0.7490257024765015
# Epoch: 210 Loss G.: 0.8355662226676941
# Epoch: 220 Loss D.: 0.7236282229423523
# Epoch: 220 Loss G.: 0.6930729150772095
# Epoch: 230 Loss D.: 0.7002187371253967
# Epoch: 230 Loss G.: 0.7445688247680664
# Epoch: 240 Loss D.: 0.6991192102432251
# Epoch: 240 Loss G.: 0.662642240524292
# Epoch: 250 Loss D.: 0.6935151815414429
# Epoch: 250 Loss G.: 0.6896781921386719
# Epoch: 260 Loss D.: 0.698371946811676
# Epoch: 260 Loss G.: 0.6947743892669678
# Epoch: 270 Loss D.: 0.6922665238380432
# Epoch: 270 Loss G.: 0.6867215633392334
# Epoch: 280 Loss D.: 0.691353976726532
# Epoch: 280 Loss G.: 0.7125958204269409
# Epoch: 290 Loss D.: 0.6840258836746216
# Epoch: 290 Loss G.: 0.6985304355621338

# %%
latent_space_samples = torch.randn(100, 2)
generated_samples = generator(latent_space_samples)

# %%
generated_samples = generated_samples.detach()
plt.plot(generated_samples[:, 0], generated_samples[:, 1], ".")

# %%
plt.plot(train_data[:, 0], train_data[:, 1], ".")

# %%
from __future__ import print_function
#%matplotlib inline
import argparse
import os
import random
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# %%
# Number of workers for dataloader
workers = 1

# Batch size during training
batch_size = 128

# Spatial size of training images. All images will be resized to this
#   size using a transformer.
image_size = 64

# Number of channels in the training images. For color images this is 3
nc = 1

# Size of z latent vector (i.e. size of generator input)
nz = 100

# Size of feature maps in generator
ngf = 64

# Size of feature maps in discriminator
ndf = 64

# Number of training epochs
num_epochs = 5

# Learning rate for optimizers
lr = 0.0002

# Beta1 hyperparam for Adam optimizers
beta1 = 0.5

# Number of GPUs available. Use 0 for CPU mode.
ngpu = 1

# %%
dataloader = torch.utils.data.DataLoader(
    datasets.MNIST(
        "../../data/mnist",
        train=True,
        download=True,
        transform=transforms.Compose(
            [transforms.Resize(image_size),transforms.CenterCrop(image_size), transforms.ToTensor(), transforms.Normalize([0.5], [0.5])]
        ),
    ),
    batch_size=batch_size,
    shuffle=True,
)

# %%
# Decide which device we want to run on
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")

# Plot some training images
real_batch = next(iter(dataloader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
class Generator(nn.Module):
    def __init__(self, ngpu):
        super(Generator, self).__init__()
        self.ngpu = ngpu
        self.main = nn.Sequential(
            # input is Z, going into a convolution
            nn.ConvTranspose2d( nz, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
            # state size. (ngf*8) x 4 x 4
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),
            # state size. (ngf*4) x 8 x 8
            nn.ConvTranspose2d( ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            # state size. (ngf*2) x 16 x 16
            nn.ConvTranspose2d( ngf * 2, ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.ReLU(True),
            # state size. (ngf) x 32 x 32
            nn.ConvTranspose2d( ngf, nc, 4, 2, 1, bias=False),
            nn.Tanh()
            # state size. (nc) x 64 x 64
        )

    def forward(self, input):
        return self.main(input)

# %%
netG = Generator(ngpu).to(device)

# Handle multi-gpu if desired
if (device.type == 'cuda') and (ngpu > 1):
    netG = nn.DataParallel(netG, list(range(ngpu)))

# Apply the weights_init function to randomly initialize all weights
#  to mean=0, stdev=0.2.
netG.apply(weights_init)

# Print the model
print(netG)
# Out:
# Generator(
#   (main): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): ConvTranspose2d(64, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (13): Tanh()
#   )
# )

# %%
class Discriminator(nn.Module):
    def __init__(self, ngpu):
        super(Discriminator, self).__init__()
        self.ngpu = ngpu
        self.main = nn.Sequential(
            # input is (nc) x 64 x 64
            nn.Conv2d(nc, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf) x 32 x 32
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*2) x 16 x 16
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*4) x 8 x 8
            nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*8) x 4 x 4
            nn.Conv2d(ndf * 8, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
        )

    def forward(self, input):
        return self.main(input)

# %%
# Create the Discriminator
netD = Discriminator(ngpu).to(device)

# Handle multi-gpu if desired
if (device.type == 'cuda') and (ngpu > 1):
    netD = nn.DataParallel(netD, list(range(ngpu)))

# Apply the weights_init function to randomly initialize all weights
#  to mean=0, stdev=0.2.
netD.apply(weights_init)

# Print the model
print(netD)
# Out:
# Discriminator(
#   (main): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (12): Sigmoid()
#   )
# )

# %%
# Initialize BCELoss function
criterion = nn.BCELoss()

# Create batch of latent vectors that we will use to visualize
#  the progression of the generator
fixed_noise = torch.randn(64, nz, 1, 1, device=device)

# Establish convention for real and fake labels during training
real_label = 1.
fake_label = 0.

# Setup Adam optimizers for both G and D
optimizerD = optim.Adam(netD.parameters(), lr=lr, betas=(beta1, 0.999))
optimizerG = optim.Adam(netG.parameters(), lr=lr, betas=(beta1, 0.999))

# %%
img_list = []
G_losses = []
D_losses = []
iters = 0

print("Starting Training Loop...")
# For each epoch
for epoch in range(1):
    # For each batch in the dataloader
    for i, data in enumerate(dataloader, 0):

        ############################
        # (1) Update D network: maximize log(D(x)) + log(1 - D(G(z)))
        ###########################
        ## Train with all-real batch
        netD.zero_grad()
        # Format batch
        real_cpu = data[0].to(device)
        b_size = real_cpu.size(0)
        label = torch.full((b_size,), real_label, dtype=torch.float, device=device)
        # Forward pass real batch through D
        output = netD(real_cpu).view(-1)
        # Calculate loss on all-real batch
        errD_real = criterion(output, label)
        # Calculate gradients for D in backward pass
        errD_real.backward()
        D_x = output.mean().item()

        ## Train with all-fake batch
        # Generate batch of latent vectors
        noise = torch.randn(b_size, nz, 1, 1, device=device)
        # Generate fake image batch with G
        fake = netG(noise)
        label.fill_(fake_label)
        # Classify all fake batch with D
        output = netD(fake.detach()).view(-1)
        # Calculate D's loss on the all-fake batch
        errD_fake = criterion(output, label)
        # Calculate the gradients for this batch
        errD_fake.backward()
        D_G_z1 = output.mean().item()
        # Add the gradients from the all-real and all-fake batches
        errD = errD_real + errD_fake
        # Update D
        optimizerD.step()

        ############################
        # (2) Update G network: maximize log(D(G(z)))
        ###########################
        netG.zero_grad()
        label.fill_(real_label)  # fake labels are real for generator cost
        # Since we just updated D, perform another forward pass of all-fake batch through D
        output = netD(fake).view(-1)
        # Calculate G's loss based on this output
        errG = criterion(output, label)
        # Calculate gradients for G
        errG.backward()
        D_G_z2 = output.mean().item()
        # Update G
        optimizerG.step()

        # Output training stats
        if i % 50 == 0:
            print('[%d/%d][%d/%d]\tLoss_D: %.4f\tLoss_G: %.4f\tD(x): %.4f\tD(G(z)): %.4f / %.4f'
                  % (epoch, num_epochs, i, len(dataloader),
                     errD.item(), errG.item(), D_x, D_G_z1, D_G_z2))

        # Save Losses for plotting later
        G_losses.append(errG.item())
        D_losses.append(errD.item())

        # Check how the generator is doing by saving G's output on fixed_noise
        if (iters % 500 == 0) or ((epoch == num_epochs-1) and (i == len(dataloader)-1)):
            with torch.no_grad():
                fake = netG(fixed_noise).detach().cpu()
            img_list.append(vutils.make_grid(fake, padding=2, normalize=True))

        iters += 1
# Out:
# Starting Training Loop...
# [0/5][0/469]	Loss_D: 1.6822	Loss_G: 4.3113	D(x): 0.4907	D(G(z)): 0.5041 / 0.0234
# [0/5][50/469]	Loss_D: 0.0726	Loss_G: 9.9791	D(x): 0.9783	D(G(z)): 0.0441 / 0.0001
# [0/5][100/469]	Loss_D: 1.6344	Loss_G: 31.1526	D(x): 0.9973	D(G(z)): 0.7472 / 0.0000
# [0/5][150/469]	Loss_D: 0.1134	Loss_G: 5.0650	D(x): 0.9625	D(G(z)): 0.0677 / 0.0093
# [0/5][200/469]	Loss_D: 0.4258	Loss_G: 4.3303	D(x): 0.9191	D(G(z)): 0.2465 / 0.0220
# [0/5][250/469]	Loss_D: 0.1777	Loss_G: 2.4471	D(x): 0.8869	D(G(z)): 0.0354 / 0.1205
# [0/5][300/469]	Loss_D: 0.1976	Loss_G: 3.5047	D(x): 0.9266	D(G(z)): 0.1062 / 0.0431
# [0/5][350/469]	Loss_D: 3.5635	Loss_G: 12.0766	D(x): 0.9953	D(G(z)): 0.9530 / 0.0000
# [0/5][400/469]	Loss_D: 0.2144	Loss_G: 2.7371	D(x): 0.8636	D(G(z)): 0.0536 / 0.0910
# [0/5][450/469]	Loss_D: 0.1234	Loss_G: 3.4914	D(x): 0.9557	D(G(z)): 0.0675 / 0.0458

# %%
fig = plt.figure(figsize=(8,8))
plt.axis("off")
ims = [[plt.imshow(np.transpose(i,(1,2,0)), animated=True)] for i in img_list]
ani = animation.ArtistAnimation(fig, ims, interval=1000, repeat_delay=1000, blit=True)

HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgb796d23c7c0c4330b2bb30784b198159">
#   <div class="anim-controls">
#     <input id="_anim_sliderb796d23c7c0c4330b2bb30784b198159" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animb796d23c7c0c4330b2bb30784b198159.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animb796d23c7c0c4330b2bb30784b198159.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animb796d23c7c0c4330b2bb30784b198159.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animb796d23c7c0c4330b2bb30784b198159.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animb796d23c7c0c4330b2bb30784b198159.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animb796d23c7c0c4330b2bb30784b198159.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animb796d23c7c0c4330b2bb30784b198159.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animb796d23c7c0c4330b2bb30784b198159.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animb796d23c7c0c4330b2bb30784b198159.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animb796d23c7c0c4330b2bb30784b198159.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectb796d23c7c0c4330b2bb30784b198159" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_b796d23c7c0c4330b2bb30784b198159"
#              >
#       <label for="_anim_radio1_b796d23c7c0c4330b2bb30784b198159">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_b796d23c7c0c4330b2bb30784b198159"
#              checked>
#       <label for="_anim_radio2_b796d23c7c0c4330b2bb30784b198159">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_b796d23c7c0c4330b2bb30784b198159"
#              >
#       <label for="_anim_radio3_b796d23c7c0c4330b2bb30784b198159">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb796d23c7c0c4330b2bb30784b198159";
#     var slider_id = "_anim_sliderb796d23c7c0c4330b2bb30784b198159";
#     var loop_select_id = "_anim_loop_selectb796d23c7c0c4330b2bb30784b198159";
#     var frames = new Array(1);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAgAElEQVR4nOy9WW9k53U1vGqe57lYVSzO7G5SPUrd\
# kpPXcJwEuQoCA0F+TqJfkFzkLzjIXRAbMWDEgyTbklot9cjm0JyKVcWa53k89V501g75Xkb4PiPg\
# swDDbTebVeec5zzP3muvvbZusVgsoKCgoKCgoKBwg6D/Y38BBQUFBQUFBYX/v6ECIAUFBQUFBYUb\
# BxUAKSgoKCgoKNw4qABIQUFBQUFB4cZBBUAKCgoKCgoKNw4qAFJQUFBQUFC4cVABkIKCgoKCgsKN\
# gwqAFBQUFBQUFG4cVACkoKCgoKCgcOOgAiAFBQUFBQWFGwcVACkoKCgoKCjcOKgASEFBQUFBQeHG\
# QQVACgoKCgoKCjcOKgBSUFBQUFBQuHFQAZCCgoKCgoLCjYMKgBQUFBQUFBRuHFQApKCgoKCgoHDj\
# oAIgBQUFBQUFhRsHFQApKCgoKCg

# %%
real_batch = next(iter(dataloader))

# Plot the real images
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Real Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=5, normalize=True).cpu(),(1,2,0)))

# Plot the fake images from the last epoch
plt.subplot(1,2,2)
plt.axis("off")
plt.title("Fake Images")
plt.imshow(np.transpose(img_list[-1],(1,2,0)))
plt.show()

# %%
import matplotlib.pyplot as plt
import itertools
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.datasets as dset
import torchvision.transforms as transforms

from torch.autograd import Variable
from torch.utils.data.dataset import Dataset

# %%
img_size = 64
n_epochs = 5
batch_size = 64
learning_rate = 0.0002

# %%
transform = transforms.Compose([
    transforms.Scale(img_size),
    transforms.ToTensor(),
])

train_loader = torch.utils.data.DataLoader(
    dset.FashionMNIST('fashion', train = True, 
                      download = True, transform = transform),
    batch_size = batch_size,
    shuffle = True
)
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py:280: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   "please use transforms.Resize instead.")

# %%
class discriminator_model(nn.Module):

  def __init__(self):
    super(discriminator_model, self).__init__()
    self.conv1 = nn.Conv2d(1, 128, 4, 2, 1)
    self.conv2 = nn.Conv2d(128, 256, 4, 2, 1)
    self.conv2_bn = nn.BatchNorm2d(256)
    self.conv3 = nn.Conv2d(256, 512, 4, 2, 1)
    self.conv3_bn = nn.BatchNorm2d(512)
    self.conv4 = nn.Conv2d(512, 1024, 4, 2, 1)
    self.conv4_bn = nn.BatchNorm2d(1024)
    self.conv5 = nn.Conv2d(1024, 1, 4, 1, 0)
    
  def weight_init(self):
    for m in self._modules:
      normal_init(self._modules[m])
      
  def forward(self, input):
    x = F.leaky_relu(self.conv1(input), 0.2)
    x = F.leaky_relu(self.conv2_bn(self.conv2(x)), 0.2)
    x = F.leaky_relu(self.conv3_bn(self.conv3(x)), 0.2)
    x = F.leaky_relu(self.conv4_bn(self.conv4(x)), 0.2)
    x = torch.sigmoid(self.conv5(x))
    return x

# %%
def normal_init(m):
  if isinstance(m, nn.ConvTranspose2d) or isinstance(m, nn.Conv2d):
    m.weight.data.normal_(0.0, 0.02)
    m.bias.data.zero_()

# %%
class generator_model(nn.Module):

  def __init__(self):
    super(generator_model, self).__init__()
    self.deconv1 = nn.ConvTranspose2d(100, 1024, 4, 1, 0)
    self.deconv1_bn = nn.BatchNorm2d(1024)
    self.deconv2 = nn.ConvTranspose2d(1024, 512, 4, 2, 1)
    self.deconv2_bn = nn.BatchNorm2d(512)
    self.deconv3 = nn.ConvTranspose2d(512, 256, 4, 2, 1)
    self.deconv3_bn = nn.BatchNorm2d(256)
    self.deconv4 = nn.ConvTranspose2d(256, 128, 4, 2, 1)
    self.deconv4_bn = nn.BatchNorm2d(128)
    self.deconv5 = nn.ConvTranspose2d(128, 1, 4, 2, 1)
    
  def weight_init(self):
    for m in self._modules:
      normal_init(self._modules[m])
      
  def forward(self, input):
    x = F.relu(self.deconv1_bn(self.deconv1(input)))
    x = F.relu(self.deconv2_bn(self.deconv2(x)))
    x = F.relu(self.deconv3_bn(self.deconv3(x)))
    x = F.relu(self.deconv4_bn(self.deconv4(x)))
    x = torch.tanh(self.deconv5(x))
    return x

# %%
def plot_output():
  z_ = torch.randn((5*5, 100)).view(-1, 100, 1, 1)
  z_ = Variable(z_.cuda(), volatile = True)
  
  generator.eval()
  test_images = generator(z_)
  generator.train()
  
  grid_size = 5
  fig, ax = plt.subplots(grid_size, grid_size, figsize = (5, 5))
  for i, j in itertools.product(range(grid_size), range(grid_size)):
    ax[i, j].get_xaxis().set_visible(False)
    ax[i, j].get_yaxis().set_visible(False)
  for k in range(grid_size * grid_size):
    i = k // grid_size
    j = k % grid_size
    ax[i, j].cla()
    ax[i, j].imshow(test_images[k, 0].cpu().data.numpy(),
                    cmap = 'gray')
  
  plt.show()

# %%
generator = generator_model()
discriminator = discriminator_model()
generator.weight_init()
discriminator.weight_init()

# %%
generator.cuda()
# Out:
# generator_model(
#   (deconv1): ConvTranspose2d(100, 1024, kernel_size=(4, 4), stride=(1, 1))
#   (deconv1_bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv2): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (deconv2_bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (deconv3_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv4): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (deconv4_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv5): ConvTranspose2d(128, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
# )

# %%
discriminator.cuda()
# Out:
# discriminator_model(
#   (conv1): Conv2d(1, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (conv2): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (conv2_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (conv3_bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (conv4_bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(1024, 1, kernel_size=(4, 4), stride=(1, 1))
# )

# %%
BCE_loss = nn.BCELoss()

# %%
beta_1 = 0.5
beta_2 = 0.999

G_optimizer = optim.Adam(generator.parameters(),
                         lr = learning_rate,
                         betas = (beta_1, beta_2))
                         
D_optimizer = optim.Adam(discriminator.parameters(),
                         lr = learning_rate / 2,
                         betas = (beta_1, beta_2))

# %%
for epoch in range(n_epochs):

  D_losses = []
  G_losses = []
  qus=0
  for X, _ in train_loader:
    discriminator.zero_grad()
    mini_batch = X.size()[0]
    
    y_real_ = torch.ones(mini_batch)
    y_fake_ = torch.zeros(mini_batch)
    
    X = Variable(X.cuda())
    y_real_ = Variable(y_real_.cuda())
    y_fake_ = Variable(y_fake_.cuda())
    
    D_result = discriminator(X).squeeze()
    D_real_loss = BCE_loss(D_result, y_real_)
    
    z_ = torch.randn((mini_batch, 100)).view(-1, 100, 1, 1)
    z_ = Variable(z_.cuda())
    G_result = generator(z_)
    
    D_result = discriminator(G_result).squeeze()
    D_fake_loss = BCE_loss(D_result, y_fake_)
    D_fake_score = D_result.data.mean()
    D_train_loss = D_real_loss + D_fake_loss
    
    D_train_loss.backward()
    D_optimizer.step()
    D_losses.append(D_train_loss)
    
    generator.zero_grad()
    
    z_ = torch.randn((mini_batch, 100)).view(-1, 100, 1, 1)
    z_ = Variable(z_.cuda())
    
    G_result = generator(z_)
    D_result = discriminator(G_result).squeeze()
    G_train_loss = BCE_loss(D_result, y_real_)
    G_train_loss.backward()
    G_optimizer.step()
    G_losses.append(G_train_loss)
    print('Epoch {} Step {} - loss_d: {:.3f}, loss_g: {:.3f}'.format((epoch + 1),(qus + 1),
                                                           torch.mean(torch.FloatTensor(D_losses)),
                                                           torch.mean(torch.FloatTensor(G_losses))))
    qus+=1
  print('Epoch {} - loss_d: {:.3f}, loss_g: {:.3f}'.format((epoch + 1),
                                                           torch.mean(torch.FloatTensor(D_losses)),
                                                           torch.mean(torch.FloatTensor(G_losses))))
                                                           
  #plot_output()
# Out:
# Epoch 1 Step 1 - loss_d: 1.779, loss_g: 5.487
# Epoch 1 Step 2 - loss_d: 3.446, loss_g: 5.454
# Epoch 1 Step 3 - loss_d: 3.252, loss_g: 6.801
# Epoch 1 Step 4 - loss_d: 2.672, loss_g: 7.946
# Epoch 1 Step 5 - loss_d: 2.369, loss_g: 8.649
# Epoch 1 Step 6 - loss_d: 2.170, loss_g: 9.317
# Epoch 1 Step 7 - loss_d: 2.067, loss_g: 9.792
# Epoch 1 Step 8 - loss_d: 1.908, loss_g: 10.343
# Epoch 1 Step 9 - loss_d: 1.743, loss_g: 10.485
# Epoch 1 Step 10 - loss_d: 1.672, loss_g: 11.287
# Epoch 1 Step 11 - loss_d: 1.525, loss_g: 11.652
# Epoch 1 Step 12 - loss_d: 1.422, loss_g: 11.373
# Epoch 1 Step 13 - loss_d: 1.542, loss_g: 12.489
# Epoch 1 Step 14 - loss_d: 1.458, loss_g: 13.530
# Epoch 1 Step 15 - loss_d: 1.370, loss_g: 13.764
# Epoch 1 Step 16 - loss_d: 1.303, loss_g: 13.361
# Epoch 1 Step 17 - loss_d: 1.402, loss_g: 14.235
# Epoch 1 Step 18 - loss_d: 1.337, loss_g: 15.317
# Epoch 1 Step 19 - loss_d: 1.290, loss_g: 16.297
# Epoch 1 Step 20 - loss_d: 1.244, loss_g: 17.126
# Epoch 1 Step 21 - loss_d: 1.185, loss_g: 17.714
# Epoch 1 Step 22 - loss_d: 1.137, loss_g: 17.729
# Epoch 1 Step 23 - loss_d: 1.118, loss_g: 17.862
# Epoch 1 Step 24 - loss_d: 1.078, loss_g: 17.735
# Epoch 1 Step 25 - loss_d: 1.080, loss_g: 18.156
# Epoch 1 Step 26 - loss_d: 1.087, loss_g: 18.441
# Epoch 1 Step 27 - loss_d: 1.058, loss_g: 18.082
# Epoch 1 Step 28 - loss_d: 1.211, loss_g: 18.661
# Epoch 1 Step 29 - loss_d: 1.193, loss_g: 19.569
# Epoch 1 Step 30 - loss_d: 1.188, loss_g: 20.501
# Epoch 1 Step 31 - loss_d: 1.161, loss_g: 21.390
# Epoch 1 Step 32 - loss_d: 1.129, loss_g: 22.207
# Epoch 1 Step 33 - loss_d: 1.099, loss_g: 22.951
# Epoch 1 Step 34 - loss_d: 1.067, loss_g: 23.647
# Epoch 1 Step 35 - loss_d: 1.039, loss_g: 24.291
# Epoch 1 Step 36 - loss_d: 1.010, loss_g: 24.893
# Epoch 1 Step 37 - loss_d: 0.983, loss_g: 25.457
# Epoch 1 Step 38 - loss_d: 0.966, loss_g: 25.986
# Epoch 1 Step 39 - loss_d: 0.941, loss_g: 26.465
# Epoch 1 Step 40 - loss_d: 0.918, loss_g: 26.937
# Epoch 1 Step 41 - loss_d: 0.896, loss_g: 27.380
# Epoch 1 Step 42 - loss_d: 0.875, loss_g: 27.794
# Epoch 1 Step 43 - loss_d: 0.854, loss_g: 28.194
# Epoch 1 Step 44 - loss_d: 0.835, loss_g: 28.576
# Epoch 1 Step 45 - loss_d: 0.816, loss_g: 28.936
# Epoch 1 Step 46 - loss_d: 0.799, loss_g: 29.284
# Epoch 1 Step 47 - loss_d: 0.782, loss_g: 29.613
# Epoch 1 Step 48 - loss_d: 0.765, loss_g: 29.932
# Epoch 1 Step 49 - loss_d: 0.750, loss_g: 30.234
# Epoch 1 Step 50 - loss_d: 0.736, loss_g: 30.529
# Epoch 1 Step 51 - loss_d: 0.721, loss_g: 30.799
# Epoch 1 Step 52 - loss_d: 0.707, loss_g: 31.072
# Epoch 1 Step 53 - loss_d: 0.694, loss_g: 31.328
# Epoch 1 Step 54 - loss_d: 0.681, loss_g: 31.578
# Epoch 1 Step 55 - loss_d: 0.669, loss_g: 31.814
# Epoch 1 Step 56 - loss_d: 0.657, loss_g: 32.042
# Epoch 1 Step 57 - loss_d: 0.646, loss_g: 32.262
# Epoch 1 Step 58 - loss_d: 0.634, loss_g: 32.472
# Epoch 1 Step 59 - loss_d: 0.624, loss_g: 32.678
# Epoch 1 Step 60 - loss_d: 0.614, loss_g: 32.878
# Epoch 1 Step 61 - loss_d: 0.604, loss_g: 33.063
# Epoch 1 Step 62 - loss_d: 0.594, loss_g: 33.244
# Epoch 1 Step 63 - loss_d: 0.585, loss_g: 33.424
# Epoch 1 Step 64 - loss_d: 0.575, loss_g: 33.592
# Epoch 1 Step 65 - loss_d: 0.567, loss_g: 33.754
# Epoch 1 Step 66 - loss_d: 0.558, loss_g: 33.913
# Epoch 1 Step 67 - loss_d: 0.550, loss_g: 34.069
# Epoch 1 Step 68 - loss_d: 0.542, loss_g: 34.218
# Epoch 1 Step 69 - loss_d: 0.534, loss_g: 34.364
# Epoch 1 Step 70 - loss_d: 0.526, loss_g: 34.506
# Epoch 1 Step 71 - loss_d: 0.519, loss_g: 34.645
# Epoch 1 Step 72 - loss_d: 0.512, loss_g: 34.780
# Epoch 1 Step 73 - loss_d: 0.505, loss_g: 34.905
# Epoch 1 Step 74 - loss_d: 0.498, loss_g: 35.024
# Epoch 1 Step 75 - loss_d: 0.492, loss_g: 35.134
# Epoch 1 Step 76 - loss_d: 0.485, loss_g: 35.242
# Epoch 1 Step 77 - loss_d: 0.479, loss_g: 35.347
# Epoch 1 Step 78 - loss_d: 0.473, loss_g: 35.450
# Epoch 1 Step 79 - loss_d: 0.467, loss_g: 35.540
# Epoch 1 Step 80 - loss_d: 0.461, loss_g: 35.632
# Epoch 1 Step 81 - loss_d: 0.456, loss_g: 35.726
# Epoch 1 Step 82 - loss_d: 0.450, loss_g: 35.814
# Epoch 1 Step 83 - loss_d: 0.445, loss_g: 35.899
# Epoch 1 Step 84 - loss_d: 0.439, loss_g: 35.978
# Epoch 1 Step 85 - loss_d: 0.434, loss_g: 36.055
# Epoch 1 Step 86 - loss_d: 0.429, loss_g: 36.129
# Epoch 1 Step 87 - loss_d: 0.425, loss_g: 36.199
# Epoch 1 Step 88 - loss_d: 0.420, loss_g: 36.269
# Epoch 1 Step 89 - loss_d: 0.415, loss_g: 36.333
# Epoch 1 Step 90 - loss_d: 0.411, loss_g: 36.399
# Epoch 1 Step 91 - loss_d: 0.406, loss_g: 36.463
# Epoch 1 Step 92 - loss_d: 0.402, loss_g: 36.520
# Epoch 1 Step 93 - loss_d: 0.397, loss_g: 36.580
# Epoch 1 Step 94 - loss_d: 0.393, loss_g: 36.641
# Epoch 1 Step 95 - loss_d: 0.389, loss_g: 36.696
# Epoch 1 Step 96 - loss_d: 0.385, loss_g: 36.749
# Epoch 1 Step 97 - loss_d: 0.381, loss_g: 36.802
# Epoch 1 Step 98 - loss_d: 0.378, loss_g: 36.846
# Epoch 1 Step 99 - loss_d: 0.374, loss_g: 36.896
# Epoch 1 Step 100 - loss_d: 0.370, loss_g: 36.943
# Epoch 1 Step 101 - loss_d: 0.367, loss_g: 36.989
# Epoch 1 Step 102 - loss_d: 0.363, loss_g: 37.031
# Epoch 1 Step 103 - loss_d: 0.359, loss_g: 37.077
# Epoch 1 Step 104 - loss_d: 0.356, loss_g: 37.121
# Epoch 1 Step 105 - loss_d: 0.353, loss_g: 37.163
# Epoch 1 Step 106 - loss_d: 0.349, loss_g: 37.200
# Epoch 1 Step 107 - loss_d: 0.346, loss_g: 37.237
# Epoch 1 Step 108 - loss_d: 0.343, loss_g: 37.276
# Epoch 1 Step 109 - loss_d: 0.340, loss_g: 37.313
# Epoch 1 Step 110 - loss_d: 0.337, loss_g: 37.348
# Epoch 1 Step 111 - loss_d: 0.334, loss_g: 37.379
# Epoch 1 Step 112 - loss_d: 0.331, loss_g: 37.406
# Epoch 1 Step 113 - loss_d: 0.328, loss_g: 37.429
# Epoch 1 Step 114 - loss_d: 0.325, loss_g: 37.452
# Epoch 1 Step 115 - loss_d: 0.322, loss_g: 37.471
# Epoch 1 Step 116 - loss_d: 0.319, loss_g: 37.488
# Epoch 1 Step 117 - loss_d: 0.317, loss_g: 37.502
# Epoch 1 Step 118 - loss_d: 0.314, loss_g: 37.514
# Epoch 1 Step 119 - loss_d: 0.311, loss_g: 37.519
# Epoch 1 Step 120 - loss_d: 0.309, loss_g: 37.516
# Epoch 1 Step 121 - loss_d: 0.306, loss_g: 37.499
# Epoch 1 Step 122 - loss_d: 0.304, loss_g: 37.443
# Epoch 1 Step 123 - loss_d: 0.301, loss_g: 37.241
# Epoch 1 Step 124 - loss_d: 0.399, loss_g: 37.375
# Epoch 1 Step 125 - loss_d: 0.489, loss_g: 37.523
# Epoch 1 Step 126 - loss_d: 0.497, loss_g: 37.635
# Epoch 1 Step 127 - loss_d: 0.493, loss_g: 37.723
# Epoch 1 Step 128 - loss_d: 0.489, loss_g: 37.801
# Epoch 1 Step 129 - loss_d: 0.485, loss_g: 37.873
# Epoch 1 Step 130 - loss_d: 0.482, loss_g: 37.941
# Epoch 1 Step 131 - loss_d: 0.478, loss_g: 38.005
# Epoch 1 Step 132 - loss_d: 0.474, loss_g: 38.068
# Epoch 1 Step 133 - loss_d: 0.471, loss_g: 38.129
# Epoch 1 Step 134 - loss_d: 0.467, loss_g: 38.191
# Epoch 1 Step 135 - loss_d: 0.464, loss_g: 38.252
# Epoch 1 Step 136 - loss_d: 0.461, loss_g: 38.309
# Epoch 1 Step 137 - loss_d: 0.457, loss_g: 38.370
# Epoch 1 Step 138 - loss_d: 0.454, loss_g: 38.424
# Epoch 1 Step 139 - loss_d: 0.451, loss_g: 38.484
# Epoch 1 Step 140 - loss_d: 0.448, loss_g: 38.541
# Epoch 1 Step 141 - loss_d: 0.445, loss_g: 38.596
# Epoch 1 Step 142 - loss_d: 0.441, loss_g: 38.651
# Epoch 1 Step 143 - loss_d: 0.439, loss_g: 38.700
# Epoch 1 Step 144 - loss_d: 0.436, loss_g: 38.751
# Epoch 1 Step 145 - loss_d: 0.434, loss_g: 38.797
# Epoch 1 Step 146 - loss_d: 0.431, loss_g: 38.846
# Epoch 1 Step 147 - loss_d: 0.428, loss_g: 38.894
# Epoch 1 Step 148 - loss_d: 0.425, loss_g: 38.941
# Epoch 1 Step 149 - loss_d: 0.422, loss_g: 38.984
# Epoch 1 Step 150 - loss_d: 0.420, loss_g: 39.027
# Epoch 1 Step 151 - loss_d: 0.417, loss_g: 39.071
# Epoch 1 Step 152 - loss_d: 0.414, loss_g: 39.110
# Epoch 1 Step 153 - loss_d: 0.411, loss_g: 39.151
# Epoch 1 Step 154 - loss_d: 0.409, loss_g: 39.190
# Epoch 1 Step 155 - loss_d: 0.406, loss_g: 39.233
# Epoch 1 Step 156 - loss_d: 0.404, loss_g: 39.272
# Epoch 1 Step 157 - loss_d: 0.401, loss_g: 39.311
# Epoch 1 Step 158 - loss_d: 0.398, loss_g: 39.354
# Epoch 1 Step 159 - loss_d: 0.396, loss_g: 39.393
# Epoch 1 Step 160 - loss_d: 0.393, loss_g: 39.433
# Epoch 1 Step 161 - loss_d: 0.391, loss_g: 39.471
# Epoch 1 Step 162 - loss_d: 0.389, loss_g: 39.509
# Epoch 1 Step 163 - loss_d: 0.386, loss_g: 39.545
# Epoch 1 Step 164 - loss_d: 0.384, loss_g: 39.583
# Epoch 1 Step 165 - loss_d: 0.382, loss_g: 39.617
# Epoch 1 Step 166 - loss_d: 0.379, loss_g: 39.651
# Epoch 1 Step 167 - loss_d: 0.377, loss_g: 39.684
# Epoch 1 Step 168 - loss_d: 0.375, loss_g: 39.720
# Epoch 1 Step 169 - loss_d: 0.373, loss_g: 39.759
# Epoch 1 Step 170 - loss_d: 0.370, loss_g: 39.789
# Epoch 1 Step 171 - loss_d: 0.368, loss_g: 39.821
# Epoch 1 Step 172 - loss_d: 0.366, loss_g: 39.854
# Epoch 1 Step 173 - loss_d: 0.364, loss_g: 39.888
# Epoch 1 Step 174 - loss_d: 0.362, loss_g: 39.919
# Epoch 1 Step 175 - loss_d: 0.360, loss_g: 39.949
# Epoch 1 Step 176 - loss_d: 0.358, loss_g: 39.978
# Epoch 1 Step 177 - loss_d: 0.356, loss_g: 40.005
# Epoch 1 Step 178 - loss_d: 0.354, loss_g: 40.033
# Epoch 1 Step 179 - loss_d: 0.352, loss_g: 40.060
# Epoch 1 Step 180 - loss_d: 0.350, loss_g: 40.090
# Epoch 1 Step 181 - loss_d: 0.348, loss_g: 40.118
# Epoch 1 Step 182 - loss_d: 0.346, loss_g: 40.147
# Epoch 1 Step 183 - loss_d: 0.344, loss_g: 40.172
# Epoch 1 Step 184 - loss_d: 0.342, loss_g: 40.200
# Epoch 1 Step 185 - loss_d: 0.340, loss_g: 40.222
# Epoch 1 Step 186 - loss_d: 0.339, loss_g: 40.244
# Epoch 1 Step 187 - loss_d: 0.337, loss_g: 40.267
# Epoch 1 Step 188 - loss_d: 0.335, loss_g: 40.287
# Epoch 1 Step 189 - loss_d: 0.333, loss_g: 40.310
# Epoch 1 Step 190 - loss_d: 0.332, loss_g: 40.329
# Epoch 1 Step 191 - loss_d: 0.330, loss_g: 40.349
# Epoch 1 Step 192 - loss_d: 0.328, loss_g: 40.367
# Epoch 1 Step 193 - loss_d: 0.326, loss_g: 40.386
# Epoch 1 Step 194 - loss_d: 0.325, loss_g: 40.408
# Epoch 1 Step 195 - loss_d: 0.323, loss_g: 40.424
# Epoch 1 Step 196 - loss_d: 0.321, loss_g: 40.442
# Epoch 1 Step 197 - loss_d: 0.320, loss_g: 40.460
# Epoch 1 Step 198 - loss_d: 0.318, loss_g: 40.477
# Epoch 1 Step 199 - loss_d: 0.317, loss_g: 40.493
# Epoch 1 Step 200 - loss_d: 0.315, loss_g: 40.510
# Epoch 1 Step 201 - loss_d: 0.313, loss_g: 40.524
# Epoch 1 Step 202 - loss_d: 0.312, loss_g: 40.540
# Epoch 1 Step 203 - loss_d: 0.310, loss_g: 40.556
# Epoch 1 Step 204 - loss_d: 0.309, loss_g: 40.571
# Epoch 1 Step 205 - loss_d: 0.307, loss_g: 40.590
# Epoch 1 Step 206 - loss_d: 0.306, loss_g: 40.606
# Epoch 1 Step 207 - loss_d: 0.304, loss_g: 40.618
# Epoch 1 Step 208 - loss_d: 0.303, loss_g: 40.631
# Epoch 1 Step 209 - loss_d: 0.301, loss_g: 40.645
# Epoch 1 Step 210 - loss_d: 0.300, loss_g: 40.658
# Epoch 1 Step 211 - loss_d: 0.299, loss_g: 40.672
# Epoch 1 Step 212 - loss_d: 0.297, loss_g: 40.683
# Epoch 1 Step 213 - loss_d: 0.296, loss_g: 40.694
# Epoch 1 Step 214 - loss_d: 0.294, loss_g: 40.706
# Epoch 1 Step 215 - loss_d: 0.293, loss_g: 40.718
# Epoch 1 Step 216 - loss_d: 0.292, loss_g: 40.726
# Epoch 1 Step 217 - loss_d: 0.290, loss_g: 40.734
# Epoch 1 Step 218 - loss_d: 0.289, loss_g: 40.741
# Epoch 1 Step 219 - loss_d: 0.288, loss_g: 40.748
# Epoch 1 Step 220 - loss_d: 0.286, loss_g: 40.754
# Epoch 1 Step 221 - loss_d: 0.285, loss_g: 40.758
# Epoch 1 Step 222 - loss_d: 0.284, loss_g: 40.762
# Epoch 1 Step 223 - loss_d: 0.283, loss_g: 40.762
# Epoch 1 Step 224 - loss_d: 0.281, loss_g: 40.766
# Epoch 1 Step 225 - loss_d: 0.280, loss_g: 40.764
# Epoch 1 Step 226 - loss_d: 0.279, loss_g: 40.755
# Epoch 1 Step 227 - loss_d: 0.278, loss_g: 40.742
# Epoch 1 Step 228 - loss_d: 0.276, loss_g: 40.720
# Epoch 1 Step 229 - loss_d: 0.275, loss_g: 40.688
# Epoch 1 Step 230 - loss_d: 0.274, loss_g: 40.626
# Epoch 1 Step 231 - loss_d: 0.314, loss_g: 40.692
# Epoch 1 Step 232 - loss_d: 0.328, loss_g: 40.773
# Epoch 1 Step 233 - loss_d: 0.329, loss_g: 40.850
# Epoch 1 Step 234 - loss_d: 0.331, loss_g: 40.913
# Epoch 1 Step 235 - loss_d: 0.330, loss_g: 40.971
# Epoch 1 Step 236 - loss_d: 0.329, loss_g: 41.024
# Epoch 1 Step 237 - loss_d: 0.327, loss_g: 41.079
# Epoch 1 Step 238 - loss_d: 0.326, loss_g: 41.130
# Epoch 1 Step 239 - loss_d: 0.325, loss_g: 41.177
# Epoch 1 Step 240 - loss_d: 0.323, loss_g: 41.224
# Epoch 1 Step 241 - loss_d: 0.322, loss_g: 41.270
# Epoch 1 Step 242 - loss_d: 0.321, loss_g: 41.317
# Epoch 1 Step 243 - loss_d: 0.320, loss_g: 41.361
# Epoch 1 Step 244 - loss_d: 0.319, loss_g: 41.403
# Epoch 1 Step 245 - loss_d: 0.318, loss_g: 41.447
# Epoch 1 Step 246 - loss_d: 0.316, loss_g: 41.488
# Epoch 1 Step 247 - loss_d: 0.315, loss_g: 41.530
# Epoch 1 Step 248 - loss_d: 0.314, loss_g: 41.573
# Epoch 1 Step 249 - loss_d: 0.313, loss_g: 41.615
# Epoch 1 Step 250 - loss_d: 0.311, loss_g: 41.655
# Epoch 1 Step 251 - loss_d: 0.310, loss_g: 41.694
# Epoch 1 Step 252 - loss_d: 0.309, loss_g: 41.728
# Epoch 1 Step 253 - loss_d: 0.308, loss_g: 41.766
# Epoch 1 Step 254 - loss_d: 0.307, loss_g: 41.804
# Epoch 1 Step 255 - loss_d: 0.306, loss_g: 41.840
# Epoch 1 Step 256 - loss_d: 0.304, loss_g: 41.875
# Epoch 1 Step 257 - loss_d: 0.303, loss_g: 41.911
# Epoch 1 Step 258 - loss_d: 0.302, loss_g: 41.948
# Epoch 1 Step 259 - loss_d: 0.301, loss_g: 41.983
# Epoch 1 Step 260 - loss_d: 0.300, loss_g: 42.016
# Epoch 1 Step 261 - loss_d: 0.299, loss_g: 42.050
# Epoch 1 Step 262 - loss_d: 0.297, loss_g: 42.082
# Epoch 1 Step 263 - loss_d: 0.296, loss_g: 42.116
# Epoch 1 Step 264 - loss_d: 0.295, loss_g: 42.149
# Epoch 1 Step 265 - loss_d: 0.294, loss_g: 42.179
# Epoch 1 Step 266 - loss_d: 0.293, loss_g: 42.213
# Epoch 1 Step 267 - loss_d: 0.292, loss_g: 42.247
# Epoch 1 Step 268 - loss_d: 0.291, loss_g: 42.277
# Epoch 1 Step 269 - loss_d: 0.290, loss_g: 42.308
# Epoch 1 Step 270 - loss_d: 0.289, loss_g: 42.336
# Epoch 1 Step 271 - loss_d: 0.288, loss_g: 42.366
# Epoch 1 Step 272 - loss_d: 0.286, loss_g: 42.399
# Epoch 1 Step 273 - loss_d: 0.285, loss_g: 42.424
# Epoch 1 Step 274 - loss_d: 0.284, loss_g: 42.453
# Epoch 1 Step 275 - loss_d: 0.283, loss_g: 42.481
# Epoch 1 Step 276 - loss_d: 0.282, loss_g: 42.509
# Epoch 1 Step 277 - loss_d: 0.281, loss_g: 42.539
# Epoch 1 Step 278 - loss_d: 0.280, loss_g: 42.565
# Epoch 1 Step 279 - loss_d: 0.279, loss_g: 42.594
# Epoch 1 Step 280 - loss_d: 0.278, loss_g: 42.622
# Epoch 1 Step 281 - loss_d: 0.277, loss_g: 42.648
# Epoch 1 Step 282 - loss_d: 0.276, loss_g: 42.675
# Epoch 1 Step 283 - loss_d: 0.275, loss_g: 42.701
# Epoch 1 Step 284 - loss_d: 0.274, loss_g: 42.729
# Epoch 1 Step 285 - loss_d: 0.273, loss_g: 42.758
# Epoch 1 Step 286 - loss_d: 0.273, loss_g: 42.787
# Epoch 1 Step 287 - loss_d: 0.272, loss_g: 42.810
# Epoch 1 Step 288 - loss_d: 0.271, loss_g: 42.833
# Epoch 1 Step 289 - loss_d: 0.270, loss_g: 42.856
# Epoch 1 Step 290 - loss_d: 0.269, loss_g: 42.878
# Epoch 1 Step 291 - loss_d: 0.268, loss_g: 42.902
# Epoch 1 Step 292 - loss_d: 0.267, loss_g: 42.927
# Epoch 1 Step 293 - loss_d: 0.266, loss_g: 42.950
# Epoch 1 Step 294 - loss_d: 0.265, loss_g: 42.972
# Epoch 1 Step 295 - loss_d: 0.264, loss_g: 42.995
# Epoch 1 Step 296 - loss_d: 0.263, loss_g: 43.017
# Epoch 1 Step 297 - loss_d: 0.262, loss_g: 43.042
# Epoch 1 Step 298 - loss_d: 0.262, loss_g: 43.066
# Epoch 1 Step 299 - loss_d: 0.261, loss_g: 43.088
# Epoch 1 Step 300 - loss_d: 0.260, loss_g: 43.111
# Epoch 1 Step 301 - loss_d: 0.259, loss_g: 43.133
# Epoch 1 Step 302 - loss_d: 0.258, loss_g: 43.154
# Epoch 1 Step 303 - loss_d: 0.257, loss_g: 43.176
# Epoch 1 Step 304 - loss_d: 0.256, loss_g: 43.198
# Epoch 1 Step 305 - loss_d: 0.256, loss_g: 43.219
# Epoch 1 Step 306 - loss_d: 0.255, loss_g: 43.239
# Epoch 1 Step 307 - loss_d: 0.254, loss_g: 43.256
# Epoch 1 Step 308 - loss_d: 0.253, loss_g: 43.278
# Epoch 1 Step 309 - loss_d: 0.252, loss_g: 43.297
# Epoch 1 Step 310 - loss_d: 0.251, loss_g: 43.317
# Epoch 1 Step 311 - loss_d: 0.251, loss_g: 43.336
# Epoch 1 Step 312 - loss_d: 0.250, loss_g: 43.357
# Epoch 1 Step 313 - loss_d: 0.249, loss_g: 43.377
# Epoch 1 Step 314 - loss_d: 0.248, loss_g: 43.396
# Epoch 1 Step 315 - loss_d: 0.247, loss_g: 43.415
# Epoch 1 Step 316 - loss_d: 0.247, loss_g: 43.432
# Epoch 1 Step 317 - loss_d: 0.246, loss_g: 43.453
# Epoch 1 Step 318 - loss_d: 0.245, loss_g: 43.469
# Epoch 1 Step 319 - loss_d: 0.244, loss_g: 43.488
# Epoch 1 Step 320 - loss_d: 0.244, loss_g: 43.506
# Epoch 1 Step 321 - loss_d: 0.243, loss_g: 43.525
# Epoch 1 Step 322 - loss_d: 0.242, loss_g: 43.543
# Epoch 1 Step 323 - loss_d: 0.241, loss_g: 43.563
# Epoch 1 Step 324 - loss_d: 0.241, loss_g: 43.580
# Epoch 1 Step 325 - loss_d: 0.240, loss_g: 43.594
# Epoch 1 Step 326 - loss_d: 0.239, loss_g: 43.613
# Epoch 1 Step 327 - loss_d: 0.238, loss_g: 43.630
# Epoch 1 Step 328 - loss_d: 0.238, loss_g: 43.646
# Epoch 1 Step 329 - loss_d: 0.237, loss_g: 43.659
# Epoch 1 Step 330 - loss_d: 0.236, loss_g: 43.677
# Epoch 1 Step 331 - loss_d: 0.236, loss_g: 43.693
# Epoch 1 Step 332 - loss_d: 0.235, loss_g: 43.711
# Epoch 1 Step 333 - loss_d: 0.234, loss_g: 43.725
# Epoch 1 Step 334 - loss_d: 0.233, loss_g: 43.740
# Epoch 1 Step 335 - loss_d: 0.233, loss_g: 43.757
# Epoch 1 Step 336 - loss_d: 0.232, loss_g: 43.770
# Epoch 1 Step 337 - loss_d: 0.232, loss_g: 43.785
# Epoch 1 Step 338 - loss_d: 0.231, loss_g: 43.799
# Epoch 1 Step 339 - loss_d: 0.230, loss_g: 43.811
# Epoch 1 Step 340 - loss_d: 0.230, loss_g: 43.826
# Epoch 1 Step 341 - loss_d: 0.229, loss_g: 43.839
# Epoch 1 Step 342 - loss_d: 0.228, loss_g: 43.850
# Epoch 1 Step 343 - loss_d: 0.228, loss_g: 43.861
# Epoch 1 Step 344 - loss_d: 0.227, loss_g: 43.871
# Epoch 1 Step 345 - loss_d: 0.226, loss_g: 43.883
# Epoch 1 Step 346 - loss_d: 0.226, loss_g: 43.889
# Epoch 1 Step 347 - loss_d: 0.225, loss_g: 43.898
# Epoch 1 Step 348 - loss_d: 0.224, loss_g: 43.906
# Epoch 1 Step 349 - loss_d: 0.224, loss_g: 43.911
# Epoch 1 Step 350 - loss_d: 0.223, loss_g: 43.912
# Epoch 1 Step 351 - loss_d: 0.222, loss_g: 43.912
# Epoch 1 Step 352 - loss_d: 0.222, loss_g: 43.909
# Epoch 1 Step 353 - loss_d: 0.221, loss_g: 43.898
# Epoch 1 Step 354 - loss_d: 0.221, loss_g: 43.872
# Epoch 1 Step 355 - loss_d: 0.220, loss_g: 43.802
# Epoch 1 Step 356 - loss_d: 0.258, loss_g: 43.834
# Epoch 1 Step 357 - loss_d: 0.264, loss_g: 43.885
# Epoch 1 Step 358 - loss_d: 0.269, loss_g: 43.925
# Epoch 1 Step 359 - loss_d: 0.270, loss_g: 43.959
# Epoch 1 Step 360 - loss_d: 0.269, loss_g: 43.985
# Epoch 1 Step 361 - loss_d: 0.269, loss_g: 44.011
# Epoch 1 Step 362 - loss_d: 0.268, loss_g: 44.032
# Epoch 1 Step 363 - loss_d: 0.268, loss_g: 44.053
# Epoch 1 Step 364 - loss_d: 0.267, loss_g: 44.073
# Epoch 1 Step 365 - loss_d: 0.266, loss_g: 44.093
# Epoch 1 Step 366 - loss_d: 0.265, loss_g: 44.114
# Epoch 1 Step 367 - loss_d: 0.265, loss_g: 44.130
# Epoch 1 Step 368 - loss_d: 0.264, loss_g: 44.150
# Epoch 1 Step 369 - loss_d: 0.263, loss_g: 44.164
# Epoch 1 Step 370 - loss_d: 0.263, loss_g: 44.181
# Epoch 1 Step 371 - loss_d: 0.262, loss_g: 44.198
# Epoch 1 Step 372 - loss_d: 0.261, loss_g: 44.214
# Epoch 1 Step 373 - loss_d: 0.261, loss_g: 44.234
# Epoch 1 Step 374 - loss_d: 0.260, loss_g: 44.245
# Epoch 1 Step 375 - loss_d: 0.259, loss_g: 44.257
# Epoch 1 Step 376 - loss_d: 0.259, loss_g: 44.269
# Epoch 1 Step 377 - loss_d: 0.258, loss_g: 44.276
# Epoch 1 Step 378 - loss_d: 0.257, loss_g: 44.286
# Epoch 1 Step 379 - loss_d: 0.257, loss_g: 44.289
# Epoch 1 Step 380 - loss_d: 0.256, loss_g: 44.293
# Epoch 1 Step 381 - loss_d: 0.256, loss_g: 44.289
# Epoch 1 Step 382 - loss_d: 0.255, loss_g: 44.280
# Epoch 1 Step 383 - loss_d: 0.254, loss_g: 44.264
# Epoch 1 Step 384 - loss_d: 0.254, loss_g: 44.227
# Epoch 1 Step 385 - loss_d: 0.255, loss_g: 44.165
# Epoch 1 Step 386 - loss_d: 0.261, loss_g: 44.162
# Epoch 1 Step 387 - loss_d: 0.263, loss_g: 44.178
# Epoch 1 Step 388 - loss_d: 0.266, loss_g: 44.190
# Epoch 1 Step 389 - loss_d: 0.267, loss_g: 44.189
# Epoch 1 Step 390 - loss_d: 0.266, loss_g: 44.168
# Epoch 1 Step 391 - loss_d: 0.266, loss_g: 44.136
# Epoch 1 Step 392 - loss_d: 0.266, loss_g: 44.080
# Epoch 1 Step 393 - loss_d: 0.268, loss_g: 44.009
# Epoch 1 Step 394 - loss_d: 0.270, loss_g: 43.947
# Epoch 1 Step 395 - loss_d: 0.273, loss_g: 43.862
# Epoch 1 Step 396 - loss_d: 0.285, loss_g: 43.806
# Epoch 1 Step 397 - loss_d: 0.304, loss_g: 43.722
# Epoch 1 Step 398 - loss_d: 0.308, loss_g: 43.638
# Epoch 1 Step 399 - loss_d: 0.311, loss_g: 43.557
# Epoch 1 Step 400 - loss_d: 0.314, loss_g: 43.467
# Epoch 1 Step 401 - loss_d: 0.316, loss_g: 43.394
# Epoch 1 Step 402 - loss_d: 0.323, loss_g: 43.302
# Epoch 1 Step 403 - loss_d: 0.324, loss_g: 43.211
# Epoch 1 Step 404 - loss_d: 0.325, loss_g: 43.124
# Epoch 1 Step 405 - loss_d: 0.326, loss_g: 43.032
# Epoch 1 Step 406 - loss_d: 0.326, loss_g: 42.941
# Epoch 1 Step 407 - loss_d: 0.327, loss_g: 42.852
# Epoch 1 Step 408 - loss_d: 0.329, loss_g: 42.753
# Epoch 1 Step 409 - loss_d: 0.335, loss_g: 42.677
# Epoch 1 Step 410 - loss_d: 0.343, loss_g: 42.591
# Epoch 1 Step 411 - loss_d: 0.344, loss_g: 42.501
# Epoch 1 Step 412 - loss_d: 0.346, loss_g: 42.421
# Epoch 1 Step 413 - loss_d: 0.347, loss_g: 42.336
# Epoch 1 Step 414 - loss_d: 0.348, loss_g: 42.239
# Epoch 1 Step 415 - loss_d: 0.353, loss_g: 42.165
# Epoch 1 Step 416 - loss_d: 0.357, loss_g: 42.085
# Epoch 1 Step 417 - loss_d: 0.357, loss_g: 41.995
# Epoch 1 Step 418 - loss_d: 0.357, loss_g: 41.901
# Epoch 1 Step 419 - loss_d: 0.357, loss_g: 41.813
# Epoch 1 Step 420 - loss_d: 0.357, loss_g: 41.729
# Epoch 1 Step 421 - loss_d: 0.358, loss_g: 41.636
# Epoch 1 Step 422 - loss_d: 0.360, loss_g: 41.554
# Epoch 1 Step 423 - loss_d: 0.362, loss_g: 41.465
# Epoch 1 Step 424 - loss_d: 0.362, loss_g: 41.376
# Epoch 1 Step 425 - loss_d: 0.364, loss_g: 41.297
# Epoch 1 Step 426 - loss_d: 0.365, loss_g: 41.210
# Epoch 1 Step 427 - loss_d: 0.366, loss_g: 41.130
# Epoch 1 Step 428 - loss_d: 0.368, loss_g: 41.041
# Epoch 1 Step 429 - loss_d: 0.371, loss_g: 40.975
# Epoch 1 Step 430 - loss_d: 0.378, loss_g: 40.892
# Epoch 1 Step 431 - loss_d: 0.379, loss_g: 40.801
# Epoch 1 Step 432 - loss_d: 0.386, loss_g: 40.736
# Epoch 1 Step 433 - loss_d: 0.395, loss_g: 40.658
# Epoch 1 Step 434 - loss_d: 0.396, loss_g: 40.567
# Epoch 1 Step 435 - loss_d: 0.402, loss_g: 40.491
# Epoch 1 Step 436 - loss_d: 0.404, loss_g: 40.410
# Epoch 1 Step 437 - loss_d: 0.404, loss_g: 40.325
# Epoch 1 Step 438 - loss_d: 0.407, loss_g: 40.247
# Epoch 1 Step 439 - loss_d: 0.409, loss_g: 40.162
# Epoch 1 Step 440 - loss_d: 0.411, loss_g: 40.079
# Epoch 1 Step 441 - loss_d: 0.412, loss_g: 39.997
# Epoch 1 Step 442 - loss_d: 0.413, loss_g: 39.920
# Epoch 1 Step 443 - loss_d: 0.413, loss_g: 39.837
# Epoch 1 Step 444 - loss_d: 0.414, loss_g: 39.757
# Epoch 1 Step 445 - loss_d: 0.414, loss_g: 39.680
# Epoch 1 Step 446 - loss_d: 0.414, loss_g: 39.598
# Epoch 1 Step 447 - loss_d: 0.415, loss_g: 39.518
# Epoch 1 Step 448 - loss_d: 0.416, loss_g: 39.435
# Epoch 1 Step 449 - loss_d: 0.418, loss_g: 39.355
# Epoch 1 Step 450 - loss_d: 0.419, loss_g: 39.276
# Epoch 1 Step 451 - loss_d: 0.420, loss_g: 39.197
# Epoch 1 Step 452 - loss_d: 0.420, loss_g: 39.120
# Epoch 1 Step 453 - loss_d: 0.421, loss_g: 39.041
# Epoch 1 Step 454 - loss_d: 0.421, loss_g: 38.965
# Epoch 1 Step 455 - loss_d: 0.421, loss_g: 38.886
# Epoch 1 Step 456 - loss_d: 0.422, loss_g: 38.810
# Epoch 1 Step 457 - loss_d: 0.422, loss_g: 38.734
# Epoch 1 Step 458 - loss_d: 0.423, loss_g: 38.653
# Epoch 1 Step 459 - loss_d: 0.426, loss_g: 38.588
# Epoch 1 Step 460 - loss_d: 0.430, loss_g: 38.509
# Epoch 1 Step 461 - loss_d: 0.431, loss_g: 38.434
# Epoch 1 Step 462 - loss_d: 0.432, loss_g: 38.361
# Epoch 1 Step 463 - loss_d: 0.432, loss_g: 38.283
# Epoch 1 Step 464 - loss_d: 0.433, loss_g: 38.211
# Epoch 1 Step 465 - loss_d: 0.434, loss_g: 38.134
# Epoch 1 Step 466 - loss_d: 0.435, loss_g: 38.061
# Epoch 1 Step 467 - loss_d: 0.434, loss_g: 37.987
# Epoch 1 Step 468 - loss_d: 0.435, loss_g: 37.910
# Epoch 1 Step 469 - loss_d: 0.436, loss_g: 37.839
# Epoch 1 Step 470 - loss_d: 0.437, loss_g: 37.765
# Epoch 1 Step 471 - loss_d: 0.438, loss_g: 37.693
# Epoch 1 Step 472 - loss_d: 0.439, loss_g: 37.621
# Epoch 1 Step 473 - loss_d: 0.439, loss_g: 37.548
# Epoch 1 Step 474 - loss_d: 0.440, loss_g: 37.479
# Epoch 1 Step 475 - loss_d: 0.441, loss_g: 37.403
# Epoch 1 Step 476 - loss_d: 0.442, loss_g: 37.338
# Epoch 1 Step 477 - loss_d: 0.444, loss_g: 37.264
# Epoch 1 Step 478 - loss_d: 0.445, loss_g: 37.196
# Epoch 1 Step 479 - loss_d: 0.446, loss_g: 37.127
# Epoch 1 Step 480 - loss_d: 0.445, loss_g: 37.057
# Epoch 1 Step 481 - loss_d: 0.446, loss_g: 36.989
# Epoch 1 Step 482 - loss_d: 0.446, loss_g: 36.916
# Epoch 1 Step 483 - loss_d: 0.447, loss_g: 36.850
# Epoch 1 Step 484 - loss_d: 0.448, loss_g: 36.779
# Epoch 1 Step 485 - loss_d: 0.449, loss_g: 36.711
# Epoch 1 Step 486 - loss_d: 0.450, loss_g: 36.642
# Epoch 1 Step 487 - loss_d: 0.450, loss_g: 36.575
# Epoch 1 Step 488 - loss_d: 0.450, loss_g: 36.508
# Epoch 1 Step 489 - loss_d: 0.450, loss_g: 36.439
# Epoch 1 Step 490 - loss_d: 0.451, loss_g: 36.373
# Epoch 1 Step 491 - loss_d: 0.451, loss_g: 36.304
# Epoch 1 Step 492 - loss_d: 0.452, loss_g: 36.239
# Epoch 1 Step 493 - loss_d: 0.452, loss_g: 36.170
# Epoch 1 Step 494 - loss_d: 0.453, loss_g: 36.107
# Epoch 1 Step 495 - loss_d: 0.454, loss_g: 36.041
# Epoch 1 Step 496 - loss_d: 0.455, loss_g: 35.975
# Epoch 1 Step 497 - loss_d: 0.455, loss_g: 35.911
# Epoch 1 Step 498 - loss_d: 0.455, loss_g: 35.845
# Epoch 1 Step 499 - loss_d: 0.456, loss_g: 35.782
# Epoch 1 Step 500 - loss_d: 0.456, loss_g: 35.717
# Epoch 1 Step 501 - loss_d: 0.456, loss_g: 35.655
# Epoch 1 Step 502 - loss_d: 0.456, loss_g: 35.592
# Epoch 1 Step 503 - loss_d: 0.456, loss_g: 35.526
# Epoch 1 Step 504 - loss_d: 0.456, loss_g: 35.464
# Epoch 1 Step 505 - loss_d: 0.456, loss_g: 35.400
# Epoch 1 Step 506 - loss_d: 0.457, loss_g: 35.337
# Epoch 1 Step 507 - loss_d: 0.457, loss_g: 35.276
# Epoch 1 Step 508 - loss_d: 0.457, loss_g: 35.215
# Epoch 1 Step 509 - loss_d: 0.457, loss_g: 35.150
# Epoch 1 Step 510 - loss_d: 0.458, loss_g: 35.093
# Epoch 1 Step 511 - loss_d: 0.458, loss_g: 35.032
# Epoch 1 Step 512 - loss_d: 0.458, loss_g: 34.970
# Epoch 1 Step 513 - loss_d: 0.458, loss_g: 34.912
# Epoch 1 Step 514 - loss_d: 0.458, loss_g: 34.850
# Epoch 1 Step 515 - loss_d: 0.458, loss_g: 34.790
# Epoch 1 Step 516 - loss_d: 0.458, loss_g: 34.729
# Epoch 1 Step 517 - loss_d: 0.458, loss_g: 34.668
# Epoch 1 Step 518 - loss_d: 0.458, loss_g: 34.607
# Epoch 1 Step 519 - loss_d: 0.458, loss_g: 34.551
# Epoch 1 Step 520 - loss_d: 0.459, loss_g: 34.486
# Epoch 1 Step 521 - loss_d: 0.460, loss_g: 34.432
# Epoch 1 Step 522 - loss_d: 0.461, loss_g: 34.371
# Epoch 1 Step 523 - loss_d: 0.461, loss_g: 34.311
# Epoch 1 Step 524 - loss_d: 0.461, loss_g: 34.253
# Epoch 1 Step 525 - loss_d: 0.461, loss_g: 34.194
# Epoch 1 Step 526 - loss_d: 0.460, loss_g: 34.135
# Epoch 1 Step 527 - loss_d: 0.460, loss_g: 34.075
# Epoch 1 Step 528 - loss_d: 0.460, loss_g: 34.017
# Epoch 1 Step 529 - loss_d: 0.460, loss_g: 33.959
# Epoch 1 Step 530 - loss_d: 0.460, loss_g: 33.901
# Epoch 1 Step 531 - loss_d: 0.459, loss_g: 33.845
# Epoch 1 Step 532 - loss_d: 0.459, loss_g: 33.787
# Epoch 1 Step 533 - loss_d: 0.459, loss_g: 33.730
# Epoch 1 Step 534 - loss_d: 0.459, loss_g: 33.674
# Epoch 1 Step 535 - loss_d: 0.459, loss_g: 33.614
# Epoch 1 Step 536 - loss_d: 0.459, loss_g: 33.561
# Epoch 1 Step 537 - loss_d: 0.459, loss_g: 33.506
# Epoch 1 Step 538 - loss_d: 0.459, loss_g: 33.446
# Epoch 1 Step 539 - loss_d: 0.460, loss_g: 33.394
# Epoch 1 Step 540 - loss_d: 0.460, loss_g: 33.339
# Epoch 1 Step 541 - loss_d: 0.459, loss_g: 33.284
# Epoch 1 Step 542 - loss_d: 0.459, loss_g: 33.230
# Epoch 1 Step 543 - loss_d: 0.459, loss_g: 33.174
# Epoch 1 Step 544 - loss_d: 0.459, loss_g: 33.120
# Epoch 1 Step 545 - loss_d: 0.459, loss_g: 33.066
# Epoch 1 Step 546 - loss_d: 0.459, loss_g: 33.010
# Epoch 1 Step 547 - loss_d: 0.459, loss_g: 32.960
# Epoch 1 Step 548 - loss_d: 0.460, loss_g: 32.904
# Epoch 1 Step 549 - loss_d: 0.460, loss_g: 32.852
# Epoch 1 Step 550 - loss_d: 0.460, loss_g: 32.800
# Epoch 1 Step 551 - loss_d: 0.460, loss_g: 32.747
# Epoch 1 Step 552 - loss_d: 0.460, loss_g: 32.693
# Epoch 1 Step 553 - loss_d: 0.460, loss_g: 32.640
# Epoch 1 Step 554 - loss_d: 0.459, loss_g: 32.588
# Epoch 1 Step 555 - loss_d: 0.459, loss_g: 32.535
# Epoch 1 Step 556 - loss_d: 0.459, loss_g: 32.483
# Epoch 1 Step 557 - loss_d: 0.459, loss_g: 32.431
# Epoch 1 Step 558 - loss_d: 0.459, loss_g: 32.382
# Epoch 1 Step 559 - loss_d: 0.458, loss_g: 32.330
# Epoch 1 Step 560 - loss_d: 0.458, loss_g: 32.279
# Epoch 1 Step 561 - loss_d: 0.458, loss_g: 32.229
# Epoch 1 Step 562 - loss_d: 0.457, loss_g: 32.180
# Epoch 1 Step 563 - loss_d: 0.457, loss_g: 32.131
# Epoch 1 Step 564 - loss_d: 0.457, loss_g: 32.079
# Epoch 1 Step 565 - loss_d: 0.457, loss_g: 32.036
# Epoch 1 Step 566 - loss_d: 0.459, loss_g: 31.986
# Epoch 1 Step 567 - loss_d: 0.459, loss_g: 31.937
# Epoch 1 Step 568 - loss_d: 0.459, loss_g: 31.889
# Epoch 1 Step 569 - loss_d: 0.459, loss_g: 31.839
# Epoch 1 Step 570 - loss_d: 0.459, loss_g: 31.789
# Epoch 1 Step 571 - loss_d: 0.459, loss_g: 31.742
# Epoch 1 Step 572 - loss_d: 0.459, loss_g: 31.688
# Epoch 1 Step 573 - loss_d: 0.461, loss_g: 31.649
# Epoch 1 Step 574 - loss_d: 0.465, loss_g: 31.600
# Epoch 1 Step 575 - loss_d: 0.465, loss_g: 31.548
# Epoch 1 Step 576 - loss_d: 0.466, loss_g: 31.503
# Epoch 1 Step 577 - loss_d: 0.467, loss_g: 31.454
# Epoch 1 Step 578 - loss_d: 0.467, loss_g: 31.402
# Epoch 1 Step 579 - loss_d: 0.468, loss_g: 31.357
# Epoch 1 Step 580 - loss_d: 0.468, loss_g: 31.309
# Epoch 1 Step 581 - loss_d: 0.468, loss_g: 31.260
# Epoch 1 Step 582 - loss_d: 0.468, loss_g: 31.214
# Epoch 1 Step 583 - loss_d: 0.468, loss_g: 31.166
# Epoch 1 Step 584 - loss_d: 0.468, loss_g: 31.117
# Epoch 1 Step 585 - loss_d: 0.468, loss_g: 31.070
# Epoch 1 Step 586 - loss_d: 0.468, loss_g: 31.024
# Epoch 1 Step 587 - loss_d: 0.468, loss_g: 30.978
# Epoch 1 Step 588 - loss_d: 0.468, loss_g: 30.930
# Epoch 1 Step 589 - loss_d: 0.468, loss_g: 30.886
# Epoch 1 Step 590 - loss_d: 0.468, loss_g: 30.841
# Epoch 1 Step 591 - loss_d: 0.468, loss_g: 30.794
# Epoch 1 Step 592 - loss_d: 0.467, loss_g: 30.749
# Epoch 1 Step 593 - loss_d: 0.467, loss_g: 30.703
# Epoch 1 Step 594 - loss_d: 0.467, loss_g: 30.657
# Epoch 1 Step 595 - loss_d: 0.467, loss_g: 30.610
# Epoch 1 Step 596 - loss_d: 0.467, loss_g: 30.571
# Epoch 1 Step 597 - loss_d: 0.468, loss_g: 30.521
# Epoch 1 Step 598 - loss_d: 0.470, loss_g: 30.486
# Epoch 1 Step 599 - loss_d: 0.471, loss_g: 30.442
# Epoch 1 Step 600 - loss_d: 0.471, loss_g: 30.395
# Epoch 1 Step 601 - loss_d: 0.471, loss_g: 30.352
# Epoch 1 Step 602 - loss_d: 0.471, loss_g: 30.306
# Epoch 1 Step 603 - loss_d: 0.471, loss_g: 30.262
# Epoch 1 Step 604 - loss_d: 0.471, loss_g: 30.218
# Epoch 1 Step 605 - loss_d: 0.471, loss_g: 30.173
# Epoch 1 Step 606 - loss_d: 0.471, loss_g: 30.129
# Epoch 1 Step 607 - loss_d: 0.471, loss_g: 30.084
# Epoch 1 Step 608 - loss_d: 0.471, loss_g: 30.040
# Epoch 1 Step 609 - loss_d: 0.470, loss_g: 29.996
# Epoch 1 Step 610 - loss_d: 0.470, loss_g: 29.952
# Epoch 1 Step 611 - loss_d: 0.470, loss_g: 29.909
# Epoch 1 Step 612 - loss_d: 0.470, loss_g: 29.865
# Epoch 1 Step 613 - loss_d: 0.469, loss_g: 29.821
# Epoch 1 Step 614 - loss_d: 0.469, loss_g: 29.777
# Epoch 1 Step 615 - loss_d: 0.468, loss_g: 29.735
# Epoch 1 Step 616 - loss_d: 0.468, loss_g: 29.693
# Epoch 1 Step 617 - loss_d: 0.468, loss_g: 29.648
# Epoch 1 Step 618 - loss_d: 0.468, loss_g: 29.607
# Epoch 1 Step 619 - loss_d: 0.468, loss_g: 29.563
# Epoch 1 Step 620 - loss_d: 0.468, loss_g: 29.521
# Epoch 1 Step 621 - loss_d: 0.468, loss_g: 29.482
# Epoch 1 Step 622 - loss_d: 0.468, loss_g: 29.441
# Epoch 1 Step 623 - loss_d: 0.467, loss_g: 29.400
# Epoch 1 Step 624 - loss_d: 0.467, loss_g: 29.360
# Epoch 1 Step 625 - loss_d: 0.467, loss_g: 29.318
# Epoch 1 Step 626 - loss_d: 0.466, loss_g: 29.281
# Epoch 1 Step 627 - loss_d: 0.467, loss_g: 29.237
# Epoch 1 Step 628 - loss_d: 0.468, loss_g: 29.204
# Epoch 1 Step 629 - loss_d: 0.471, loss_g: 29.161
# Epoch 1 Step 630 - loss_d: 0.472, loss_g: 29.124
# Epoch 1 Step 631 - loss_d: 0.472, loss_g: 29.085
# Epoch 1 Step 632 - loss_d: 0.472, loss_g: 29.042
# Epoch 1 Step 633 - loss_d: 0.472, loss_g: 29.004
# Epoch 1 Step 634 - loss_d: 0.472, loss_g: 28.963
# Epoch 1 Step 635 - loss_d: 0.472, loss_g: 28.922
# Epoch 1 Step 636 - loss_d: 0.472, loss_g: 28.882
# Epoch 1 Step 637 - loss_d: 0.472, loss_g: 28.842
# Epoch 1 Step 638 - loss_d: 0.472, loss_g: 28.804
# Epoch 1 Step 639 - loss_d: 0.472, loss_g: 28.764
# Epoch 1 Step 640 - loss_d: 0.472, loss_g: 28.723
# Epoch 1 Step 641 - loss_d: 0.472, loss_g: 28.683
# Epoch 1 Step 642 - loss_d: 0.472, loss_g: 28.645
# Epoch 1 Step 643 - loss_d: 0.472, loss_g: 28.603
# Epoch 1 Step 644 - loss_d: 0.473, loss_g: 28.566
# Epoch 1 Step 645 - loss_d: 0.473, loss_g: 28.526
# Epoch 1 Step 646 - loss_d: 0.473, loss_g: 28.487
# Epoch 1 Step 647 - loss_d: 0.474, loss_g: 28.448
# Epoch 1 Step 648 - loss_d: 0.474, loss_g: 28.413
# Epoch 1 Step 649 - loss_d: 0.475, loss_g: 28.374
# Epoch 1 Step 650 - loss_d: 0.475, loss_g: 28.335
# Epoch 1 Step 651 - loss_d: 0.474, loss_g: 28.299
# Epoch 1 Step 652 - loss_d: 0.474, loss_g: 28.259
# Epoch 1 Step 653 - loss_d: 0.475, loss_g: 28.222
# Epoch 1 Step 654 - loss_d: 0.475, loss_g: 28.185
# Epoch 1 Step 655 - loss_d: 0.475, loss_g: 28.146
# Epoch 1 Step 656 - loss_d: 0.475, loss_g: 28.110
# Epoch 1 Step 657 - loss_d: 0.475, loss_g: 28.071
# Epoch 1 Step 658 - loss_d: 0.475, loss_g: 28.034
# Epoch 1 Step 659 - loss_d: 0.474, loss_g: 27.996
# Epoch 1 Step 660 - loss_d: 0.474, loss_g: 27.957
# Epoch 1 Step 661 - loss_d: 0.475, loss_g: 27.923
# Epoch 1 Step 662 - loss_d: 0.475, loss_g: 27.883
# Epoch 1 Step 663 - loss_d: 0.476, loss_g: 27.847
# Epoch 1 Step 664 - loss_d: 0.476, loss_g: 27.809
# Epoch 1 Step 665 - loss_d: 0.476, loss_g: 27.772
# Epoch 1 Step 666 - loss_d: 0.475, loss_g: 27.735
# Epoch 1 Step 667 - loss_d: 0.475, loss_g: 27.699
# Epoch 1 Step 668 - loss_d: 0.476, loss_g: 27.659
# Epoch 1 Step 669 - loss_d: 0.478, loss_g: 27.630
# Epoch 1 Step 670 - loss_d: 0.481, loss_g: 27.593
# Epoch 1 Step 671 - loss_d: 0.481, loss_g: 27.554
# Epoch 1 Step 672 - loss_d: 0.481, loss_g: 27.521
# Epoch 1 Step 673 - loss_d: 0.482, loss_g: 27.485
# Epoch 1 Step 674 - loss_d: 0.482, loss_g: 27.446
# Epoch 1 Step 675 - loss_d: 0.483, loss_g: 27.413
# Epoch 1 Step 676 - loss_d: 0.483, loss_g: 27.377
# Epoch 1 Step 677 - loss_d: 0.483, loss_g: 27.341
# Epoch 1 Step 678 - loss_d: 0.482, loss_g: 27.305
# Epoch 1 Step 679 - loss_d: 0.482, loss_g: 27.271
# Epoch 1 Step 680 - loss_d: 0.482, loss_g: 27.233
# Epoch 1 Step 681 - loss_d: 0.483, loss_g: 27.202
# Epoch 1 Step 682 - loss_d: 0.483, loss_g: 27.167
# Epoch 1 Step 683 - loss_d: 0.483, loss_g: 27.132
# Epoch 1 Step 684 - loss_d: 0.484, loss_g: 27.098
# Epoch 1 Step 685 - loss_d: 0.484, loss_g: 27.064
# Epoch 1 Step 686 - loss_d: 0.484, loss_g: 27.029
# Epoch 1 Step 687 - loss_d: 0.483, loss_g: 26.993
# Epoch 1 Step 688 - loss_d: 0.483, loss_g: 26.959
# Epoch 1 Step 689 - loss_d: 0.483, loss_g: 26.924
# Epoch 1 Step 690 - loss_d: 0.483, loss_g: 26.889
# Epoch 1 Step 691 - loss_d: 0.483, loss_g: 26.855
# Epoch 1 Step 692 - loss_d: 0.483, loss_g: 26.821
# Epoch 1 Step 693 - loss_d: 0.483, loss_g: 26.789
# Epoch 1 Step 694 - loss_d: 0.483, loss_g: 26.756
# Epoch 1 Step 695 - loss_d: 0.483, loss_g: 26.725
# Epoch 1 Step 696 - loss_d: 0.483, loss_g: 26.690
# Epoch 1 Step 697 - loss_d: 0.483, loss_g: 26.661
# Epoch 1 Step 698 - loss_d: 0.484, loss_g: 26.625
# Epoch 1 Step 699 - loss_d: 0.484, loss_g: 26.594
# Epoch 1 Step 700 - loss_d: 0.485, loss_g: 26.560
# Epoch 1 Step 701 - loss_d: 0.485, loss_g: 26.527
# Epoch 1 Step 702 - loss_d: 0.485, loss_g: 26.493
# Epoch 1 Step 703 - loss_d: 0.484, loss_g: 26.460
# Epoch 1 Step 704 - loss_d: 0.485, loss_g: 26.426
# Epoch 1 Step 705 - loss_d: 0.485, loss_g: 26.395
# Epoch 1 Step 706 - loss_d: 0.485, loss_g: 26.362
# Epoch 1 Step 707 - loss_d: 0.485, loss_g: 26.329
# Epoch 1 Step 708 - loss_d: 0.485, loss_g: 26.301
# Epoch 1 Step 709 - loss_d: 0.487, loss_g: 26.266
# Epoch 1 Step 710 - loss_d: 0.489, loss_g: 26.238
# Epoch 1 Step 711 - loss_d: 0.490, loss_g: 26.205
# Epoch 1 Step 712 - loss_d: 0.492, loss_g: 26.173
# Epoch 1 Step 713 - loss_d: 0.493, loss_g: 26.144
# Epoch 1 Step 714 - loss_d: 0.493, loss_g: 26.113
# Epoch 1 Step 715 - loss_d: 0.493, loss_g: 26.078
# Epoch 1 Step 716 - loss_d: 0.494, loss_g: 26.049
# Epoch 1 Step 717 - loss_d: 0.495, loss_g: 26.017
# Epoch 1 Step 718 - loss_d: 0.495, loss_g: 25.986
# Epoch 1 Step 719 - loss_d: 0.495, loss_g: 25.958
# Epoch 1 Step 720 - loss_d: 0.496, loss_g: 25.924
# Epoch 1 Step 721 - loss_d: 0.497, loss_g: 25.894
# Epoch 1 Step 722 - loss_d: 0.497, loss_g: 25.861
# Epoch 1 Step 723 - loss_d: 0.497, loss_g: 25.830
# Epoch 1 Step 724 - loss_d: 0.497, loss_g: 25.799
# Epoch 1 Step 725 - loss_d: 0.497, loss_g: 25.767
# Epoch 1 Step 726 - loss_d: 0.497, loss_g: 25.735
# Epoch 1 Step 727 - loss_d: 0.497, loss_g: 25.705
# Epoch 1 Step 728 - loss_d: 0.497, loss_g: 25.672
# Epoch 1 Step 729 - loss_d: 0.498, loss_g: 25.644
# Epoch 1 Step 730 - loss_d: 0.498, loss_g: 25.610
# Epoch 1 Step 731 - loss_d: 0.499, loss_g: 25.583
# Epoch 1 Step 732 - loss_d: 0.500, loss_g: 25.552
# Epoch 1 Step 733 - loss_d: 0.499, loss_g: 25.521
# Epoch 1 Step 734 - loss_d: 0.500, loss_g: 25.491
# Epoch 1 Step 735 - loss_d: 0.500, loss_g: 25.460
# Epoch 1 Step 736 - loss_d: 0.500, loss_g: 25.428
# Epoch 1 Step 737 - loss_d: 0.501, loss_g: 25.401
# Epoch 1 Step 738 - loss_d: 0.501, loss_g: 25.369
# Epoch 1 Step 739 - loss_d: 0.502, loss_g: 25.342
# Epoch 1 Step 740 - loss_d: 0.503, loss_g: 25.311
# Epoch 1 Step 741 - loss_d: 0.503, loss_g: 25.280
# Epoch 1 Step 742 - loss_d: 0.503, loss_g: 25.252
# Epoch 1 Step 743 - loss_d: 0.503, loss_g: 25.221
# Epoch 1 Step 744 - loss_d: 0.503, loss_g: 25.191
# Epoch 1 Step 745 - loss_d: 0.503, loss_g: 25.161
# Epoch 1 Step 746 - loss_d: 0.503, loss_g: 25.131
# Epoch 1 Step 747 - loss_d: 0.503, loss_g: 25.103
# Epoch 1 Step 748 - loss_d: 0.503, loss_g: 25.073
# Epoch 1 Step 749 - loss_d: 0.503, loss_g: 25.043
# Epoch 1 Step 750 - loss_d: 0.502, loss_g: 25.015
# Epoch 1 Step 751 - loss_d: 0.502, loss_g: 24.984
# Epoch 1 Step 752 - loss_d: 0.502, loss_g: 24.956
# Epoch 1 Step 753 - loss_d: 0.502, loss_g: 24.928
# Epoch 1 Step 754 - loss_d: 0.502, loss_g: 24.897
# Epoch 1 Step 755 - loss_d: 0.502, loss_g: 24.872
# Epoch 1 Step 756 - loss_d: 0.503, loss_g: 24.841
# Epoch 1 Step 757 - loss_d: 0.503, loss_g: 24.813
# Epoch 1 Step 758 - loss_d: 0.503, loss_g: 24.786
# Epoch 1 Step 759 - loss_d: 0.503, loss_g: 24.756
# Epoch 1 Step 760 - loss_d: 0.503, loss_g: 24.728
# Epoch 1 Step 761 - loss_d: 0.503, loss_g: 24.700
# Epoch 1 Step 762 - loss_d: 0.504, loss_g: 24.669
# Epoch 1 Step 763 - loss_d: 0.504, loss_g: 24.643
# Epoch 1 Step 764 - loss_d: 0.506, loss_g: 24.614
# Epoch 1 Step 765 - loss_d: 0.506, loss_g: 24.585
# Epoch 1 Step 766 - loss_d: 0.506, loss_g: 24.559
# Epoch 1 Step 767 - loss_d: 0.506, loss_g: 24.530
# Epoch 1 Step 768 - loss_d: 0.506, loss_g: 24.503
# Epoch 1 Step 769 - loss_d: 0.506, loss_g: 24.475
# Epoch 1 Step 770 - loss_d: 0.506, loss_g: 24.447
# Epoch 1 Step 771 - loss_d: 0.506, loss_g: 24.421
# Epoch 1 Step 772 - loss_d: 0.507, loss_g: 24.390
# Epoch 1 Step 773 - loss_d: 0.509, loss_g: 24.367
# Epoch 1 Step 774 - loss_d: 0.510, loss_g: 24.339
# Epoch 1 Step 775 - loss_d: 0.510, loss_g: 24.310
# Epoch 1 Step 776 - loss_d: 0.510, loss_g: 24.284
# Epoch 1 Step 777 - loss_d: 0.510, loss_g: 24.257
# Epoch 1 Step 778 - loss_d: 0.510, loss_g: 24.229
# Epoch 1 Step 779 - loss_d: 0.510, loss_g: 24.202
# Epoch 1 Step 780 - loss_d: 0.510, loss_g: 24.173
# Epoch 1 Step 781 - loss_d: 0.511, loss_g: 24.150
# Epoch 1 Step 782 - loss_d: 0.512, loss_g: 24.122
# Epoch 1 Step 783 - loss_d: 0.512, loss_g: 24.095
# Epoch 1 Step 784 - loss_d: 0.512, loss_g: 24.070
# Epoch 1 Step 785 - loss_d: 0.512, loss_g: 24.041
# Epoch 1 Step 786 - loss_d: 0.513, loss_g: 24.014
# Epoch 1 Step 787 - loss_d: 0.513, loss_g: 23.988
# Epoch 1 Step 788 - loss_d: 0.513, loss_g: 23.961
# Epoch 1 Step 789 - loss_d: 0.513, loss_g: 23.934
# Epoch 1 Step 790 - loss_d: 0.513, loss_g: 23.908
# Epoch 1 Step 791 - loss_d: 0.513, loss_g: 23.879
# Epoch 1 Step 792 - loss_d: 0.514, loss_g: 23.858
# Epoch 1 Step 793 - loss_d: 0.517, loss_g: 23.831
# Epoch 1 Step 794 - loss_d: 0.518, loss_g: 23.805
# Epoch 1 Step 795 - loss_d: 0.518, loss_g: 23.779
# Epoch 1 Step 796 - loss_d: 0.518, loss_g: 23.751
# Epoch 1 Step 797 - loss_d: 0.518, loss_g: 23.724
# Epoch 1 Step 798 - loss_d: 0.519, loss_g: 23.700
# Epoch 1 Step 799 - loss_d: 0.518, loss_g: 23.673
# Epoch 1 Step 800 - loss_d: 0.519, loss_g: 23.647
# Epoch 1 Step 801 - loss_d: 0.518, loss_g: 23.620
# Epoch 1 Step 802 - loss_d: 0.519, loss_g: 23.593
# Epoch 1 Step 803 - loss_d: 0.519, loss_g: 23.569
# Epoch 1 Step 804 - loss_d: 0.518, loss_g: 23.542
# Epoch 1 Step 805 - loss_d: 0.519, loss_g: 23.516
# Epoch 1 Step 806 - loss_d: 0.519, loss_g: 23.493
# Epoch 1 Step 807 - loss_d: 0.520, loss_g: 23.465
# Epoch 1 Step 808 - loss_d: 0.521, loss_g: 23.442
# Epoch 1 Step 809 - loss_d: 0.521, loss_g: 23.419
# Epoch 1 Step 810 - loss_d: 0.521, loss_g: 23.392
# Epoch 1 Step 811 - loss_d: 0.521, loss_g: 23.369
# Epoch 1 Step 812 - loss_d: 0.521, loss_g: 23.345
# Epoch 1 Step 813 - loss_d: 0.521, loss_g: 23.319
# Epoch 1 Step 814 - loss_d: 0.521, loss_g: 23.295
# Epoch 1 Step 815 - loss_d: 0.521, loss_g: 23.270
# Epoch 1 Step 816 - loss_d: 0.521, loss_g: 23.244
# Epoch 1 Step 817 - loss_d: 0.521, loss_g: 23.221
# Epoch 1 Step 818 - loss_d: 0.522, loss_g: 23.195
# Epoch 1 Step 819 - loss_d: 0.522, loss_g: 23.172
# Epoch 1 Step 820 - loss_d: 0.522, loss_g: 23.146
# Epoch 1 Step 821 - loss_d: 0.522, loss_g: 23.123
# Epoch 1 Step 822 - loss_d: 0.522, loss_g: 23.098
# Epoch 1 Step 823 - loss_d: 0.522, loss_g: 23.074
# Epoch 1 Step 824 - loss_d: 0.522, loss_g: 23.051
# Epoch 1 Step 825 - loss_d: 0.522, loss_g: 23.026
# Epoch 1 Step 826 - loss_d: 0.522, loss_g: 23.001
# Epoch 1 Step 827 - loss_d: 0.522, loss_g: 22.978
# Epoch 1 Step 828 - loss_d: 0.522, loss_g: 22.953
# Epoch 1 Step 829 - loss_d: 0.522, loss_g: 22.928
# Epoch 1 Step 830 - loss_d: 0.522, loss_g: 22.907
# Epoch 1 Step 831 - loss_d: 0.523, loss_g: 22.881
# Epoch 1 Step 832 - loss_d: 0.523, loss_g: 22.858
# Epoch 1 Step 833 - loss_d: 0.523, loss_g: 22.834
# Epoch 1 Step 834 - loss_d: 0.522, loss_g: 22.809
# Epoch 1 Step 835 - loss_d: 0.523, loss_g: 22.787
# Epoch 1 Step 836 - loss_d: 0.523, loss_g: 22.762
# Epoch 1 Step 837 - loss_d: 0.524, loss_g: 22.739
# Epoch 1 Step 838 - loss_d: 0.524, loss_g: 22.716
# Epoch 1 Step 839 - loss_d: 0.524, loss_g: 22.693
# Epoch 1 Step 840 - loss_d: 0.524, loss_g: 22.673
# Epoch 1 Step 841 - loss_d: 0.524, loss_g: 22.649
# Epoch 1 Step 842 - loss_d: 0.524, loss_g: 22.627
# Epoch 1 Step 843 - loss_d: 0.524, loss_g: 22.603
# Epoch 1 Step 844 - loss_d: 0.524, loss_g: 22.580
# Epoch 1 Step 845 - loss_d: 0.524, loss_g: 22.559
# Epoch 1 Step 846 - loss_d: 0.524, loss_g: 22.537
# Epoch 1 Step 847 - loss_d: 0.524, loss_g: 22.514
# Epoch 1 Step 848 - loss_d: 0.523, loss_g: 22.492
# Epoch 1 Step 849 - loss_d: 0.523, loss_g: 22.468
# Epoch 1 Step 850 - loss_d: 0.523, loss_g: 22.447
# Epoch 1 Step 851 - loss_d: 0.523, loss_g: 22.425
# Epoch 1 Step 852 - loss_d: 0.523, loss_g: 22.401
# Epoch 1 Step 853 - loss_d: 0.523, loss_g: 22.381
# Epoch 1 Step 854 - loss_d: 0.523, loss_g: 22.357
# Epoch 1 Step 855 - loss_d: 0.523, loss_g: 22.336
# Epoch 1 Step 856 - loss_d: 0.523, loss_g: 22.314
# Epoch 1 Step 857 - loss_d: 0.523, loss_g: 22.293
# Epoch 1 Step 858 - loss_d: 0.523, loss_g: 22.272
# Epoch 1 Step 859 - loss_d: 0.523, loss_g: 22.248
# Epoch 1 Step 860 - loss_d: 0.524, loss_g: 22.228
# Epoch 1 Step 861 - loss_d: 0.524, loss_g: 22.204
# Epoch 1 Step 862 - loss_d: 0.524, loss_g: 22.183
# Epoch 1 Step 863 - loss_d: 0.525, loss_g: 22.159
# Epoch 1 Step 864 - loss_d: 0.525, loss_g: 22.138
# Epoch 1 Step 865 - loss_d: 0.525, loss_g: 22.115
# Epoch 1 Step 866 - loss_d: 0.525, loss_g: 22.092
# Epoch 1 Step 867 - loss_d: 0.525, loss_g: 22.072
# Epoch 1 Step 868 - loss_d: 0.525, loss_g: 22.050
# Epoch 1 Step 869 - loss_d: 0.525, loss_g: 22.027
# Epoch 1 Step 870 - loss_d: 0.525, loss_g: 22.007
# Epoch 1 Step 871 - loss_d: 0.525, loss_g: 21.985
# Epoch 1 Step 872 - loss_d: 0.525, loss_g: 21.963
# Epoch 1 Step 873 - loss_d: 0.525, loss_g: 21.942
# Epoch 1 Step 874 - loss_d: 0.525, loss_g: 21.920
# Epoch 1 Step 875 - loss_d: 0.525, loss_g: 21.900
# Epoch 1 Step 876 - loss_d: 0.525, loss_g: 21.876
# Epoch 1 Step 877 - loss_d: 0.526, loss_g: 21.861
# Epoch 1 Step 878 - loss_d: 0.529, loss_g: 21.838
# Epoch 1 Step 879 - loss_d: 0.529, loss_g: 21.816
# Epoch 1 Step 880 - loss_d: 0.529, loss_g: 21.796
# Epoch 1 Step 881 - loss_d: 0.529, loss_g: 21.775
# Epoch 1 Step 882 - loss_d: 0.529, loss_g: 21.753
# Epoch 1 Step 883 - loss_d: 0.529, loss_g: 21.733
# Epoch 1 Step 884 - loss_d: 0.530, loss_g: 21.712
# Epoch 1 Step 885 - loss_d: 0.530, loss_g: 21.692
# Epoch 1 Step 886 - loss_d: 0.530, loss_g: 21.670
# Epoch 1 Step 887 - loss_d: 0.530, loss_g: 21.650
# Epoch 1 Step 888 - loss_d: 0.531, loss_g: 21.627
# Epoch 1 Step 889 - loss_d: 0.532, loss_g: 21.609
# Epoch 1 Step 890 - loss_d: 0.532, loss_g: 21.588
# Epoch 1 Step 891 - loss_d: 0.532, loss_g: 21.566
# Epoch 1 Step 892 - loss_d: 0.532, loss_g: 21.546
# Epoch 1 Step 893 - loss_d: 0.533, loss_g: 21.524
# Epoch 1 Step 894 - loss_d: 0.533, loss_g: 21.503
# Epoch 1 Step 895 - loss_d: 0.532, loss_g: 21.483
# Epoch 1 Step 896 - loss_d: 0.532, loss_g: 21.463
# Epoch 1 Step 897 - loss_d: 0.532, loss_g: 21.442
# Epoch 1 Step 898 - loss_d: 0.532, loss_g: 21.421
# Epoch 1 Step 899 - loss_d: 0.532, loss_g: 21.401
# Epoch 1 Step 900 - loss_d: 0.532, loss_g: 21.381
# Epoch 1 Step 901 - loss_d: 0.531, loss_g: 21.363
# Epoch 1 Step 902 - loss_d: 0.531, loss_g: 21.341
# Epoch 1 Step 903 - loss_d: 0.531, loss_g: 21.324
# Epoch 1 Step 904 - loss_d: 0.532, loss_g: 21.301
# Epoch 1 Step 905 - loss_d: 0.533, loss_g: 21.285
# Epoch 1 Step 906 - loss_d: 0.534, loss_g: 21.265
# Epoch 1 Step 907 - loss_d: 0.533, loss_g: 21.243
# Epoch 1 Step 908 - loss_d: 0.534, loss_g: 21.227
# Epoch 1 Step 909 - loss_d: 0.535, loss_g: 21.207
# Epoch 1 Step 910 - loss_d: 0.535, loss_g: 21.186
# Epoch 1 Step 911 - loss_d: 0.535, loss_g: 21.166
# Epoch 1 Step 912 - loss_d: 0.536, loss_g: 21.145
# Epoch 1 Step 913 - loss_d: 0.536, loss_g: 21.126
# Epoch 1 Step 914 - loss_d: 0.536, loss_g: 21.106
# Epoch 1 Step 915 - loss_d: 0.535, loss_g: 21.086
# Epoch 1 Step 916 - loss_d: 0.535, loss_g: 21.065
# Epoch 1 Step 917 - loss_d: 0.536, loss_g: 21.048
# Epoch 1 Step 918 - loss_d: 0.536, loss_g: 21.028
# Epoch 1 Step 919 - loss_d: 0.536, loss_g: 21.008
# Epoch 1 Step 920 - loss_d: 0.536, loss_g: 20.989
# Epoch 1 Step 921 - loss_d: 0.536, loss_g: 20.969
# Epoch 1 Step 922 - loss_d: 0.536, loss_g: 20.950
# Epoch 1 Step 923 - loss_d: 0.536, loss_g: 20.931
# Epoch 1 Step 924 - loss_d: 0.536, loss_g: 20.911
# Epoch 1 Step 925 - loss_d: 0.536, loss_g: 20.892
# Epoch 1 Step 926 - loss_d: 0.536, loss_g: 20.873
# Epoch 1 Step 927 - loss_d: 0.536, loss_g: 20.855
# Epoch 1 Step 928 - loss_d: 0.536, loss_g: 20.834
# Epoch 1 Step 929 - loss_d: 0.536, loss_g: 20.816
# Epoch 1 Step 930 - loss_d: 0.537, loss_g: 20.796
# Epoch 1 Step 931 - loss_d: 0.536, loss_g: 20.776
# Epoch 1 Step 932 - loss_d: 0.537, loss_g: 20.758
# Epoch 1 Step 933 - loss_d: 0.537, loss_g: 20.739
# Epoch 1 Step 934 - loss_d: 0.537, loss_g: 20.721
# Epoch 1 Step 935 - loss_d: 0.537, loss_g: 20.701
# Epoch 1 Step 936 - loss_d: 0.537, loss_g: 20.683
# Epoch 1 Step 937 - loss_d: 0.537, loss_g: 20.665
# Epoch 1 Step 938 - loss_d: 0.536, loss_g: 20.646
# Epoch 1 - loss_d: 0.536, loss_g: 20.646
# Epoch 2 Step 1 - loss_d: 0.450, loss_g: 3.515
# Epoch 2 Step 2 - loss_d: 0.490, loss_g: 3.001
# Epoch 2 Step 3 - loss_d: 0.483, loss_g: 3.215
# Epoch 2 Step 4 - loss_d: 0.492, loss_g: 3.145
# Epoch 2 Step 5 - loss_d: 0.489, loss_g: 3.382
# Epoch 2 Step 6 - loss_d: 0.485, loss_g: 3.213
# Epoch 2 Step 7 - loss_d: 0.516, loss_g: 3.297
# Epoch 2 Step 8 - loss_d: 0.564, loss_g: 3.082
# Epoch 2 Step 9 - loss_d: 0.590, loss_g: 3.144
# Epoch 2 Step 10 - loss_d: 0.578, loss_g: 3.077
# Epoch 2 Step 11 - loss_d: 0.559, loss_g: 2.940
# Epoch 2 Step 12 - loss_d: 0.552, loss_g: 3.036
# Epoch 2 Step 13 - loss_d: 0.560, loss_g: 2.962
# Epoch 2 Step 14 - loss_d: 0.559, loss_g: 2.994
# Epoch 2 Step 15 - loss_d: 0.543, loss_g: 3.036
# Epoch 2 Step 16 - loss_d: 0.526, loss_g: 2.996
# Epoch 2 Step 17 - loss_d: 0.525, loss_g: 3.044
# Epoch 2 Step 18 - loss_d: 0.520, loss_g: 2.972
# Epoch 2 Step 19 - loss_d: 0.522, loss_g: 3.027
# Epoch 2 Step 20 - loss_d: 0.526, loss_g: 2.960
# Epoch 2 Step 21 - loss_d: 0.527, loss_g: 3.013
# Epoch 2 Step 22 - loss_d: 0.516, loss_g: 3.073
# Epoch 2 Step 23 - loss_d: 0.507, loss_g: 3.058
# Epoch 2 Step 24 - loss_d: 0.500, loss_g: 3.068
# Epoch 2 Step 25 - loss_d: 0.492, loss_g: 3.068
# Epoch 2 Step 26 - loss_d: 0.491, loss_g: 3.060
# Epoch 2 Step 27 - loss_d: 0.492, loss_g: 3.141
# Epoch 2 Step 28 - loss_d: 0.504, loss_g: 3.070
# Epoch 2 Step 29 - loss_d: 0.522, loss_g: 3.151
# Epoch 2 Step 30 - loss_d: 0.542, loss_g: 3.108
# Epoch 2 Step 31 - loss_d: 0.552, loss_g: 3.127
# Epoch 2 Step 32 - loss_d: 0.547, loss_g: 3.107
# Epoch 2 Step 33 - loss_d: 0.543, loss_g: 3.079
# Epoch 2 Step 34 - loss_d: 0.544, loss_g: 3.119
# Epoch 2 Step 35 - loss_d: 0.539, loss_g: 3.159
# Epoch 2 Step 36 - loss_d: 0.532, loss_g: 3.132
# Epoch 2 Step 37 - loss_d: 0.536, loss_g: 3.132
# Epoch 2 Step 38 - loss_d: 0.538, loss_g: 3.134
# Epoch 2 Step 39 - loss_d: 0.533, loss_g: 3.118
# Epoch 2 Step 40 - loss_d: 0.531, loss_g: 3.143
# Epoch 2 Step 41 - loss_d: 0.532, loss_g: 3.090
# Epoch 2 Step 42 - loss_d: 0.551, loss_g: 3.238
# Epoch 2 Step 43 - loss_d: 0.605, loss_g: 3.229
# Epoch 2 Step 44 - loss_d: 0.614, loss_g: 3.207
# Epoch 2 Step 45 - loss_d: 0.618, loss_g: 3.253
# ...
# Epoch 5 Step 607 - loss_d: 0.409, loss_g: 4.300
# Epoch 5 Step 608 - loss_d: 0.408, loss_g: 4.299
# Epoch 5 Step 609 - loss_d: 0.408, loss_g: 4.301
# Epoch 5 Step 610 - loss_d: 0.407, loss_g: 4.301
# Epoch 5 Step 611 - loss_d: 0.407, loss_g: 4.300
# Epoch 5 Step 612 - loss_d: 0.406, loss_g: 4.301
# Epoch 5 Step 613 - loss_d: 0.406, loss_g: 4.302
# Epoch 5 Step 614 - loss_d: 0.405, loss_g: 4.301
# Epoch 5 Step 615 - loss_d: 0.405, loss_g: 4.302
# Epoch 5 Step 616 - loss_d: 0.404, loss_g: 4.303
# Epoch 5 Step 617 - loss_d: 0.404, loss_g: 4.305
# Epoch 5 Step 618 - loss_d: 0.403, loss_g: 4.305
# Epoch 5 Step 619 - loss_d: 0.403, loss_g: 4.306
# Epoch 5 Step 620 - loss_d: 0.402, loss_g: 4.305
# Epoch 5 Step 621 - loss_d: 0.402, loss_g: 4.308
# Epoch 5 Step 622 - loss_d: 0.401, loss_g: 4.308
# Epoch 5 Step 623 - loss_d: 0.401, loss_g: 4.308
# Epoch 5 Step 624 - loss_d: 0.400, loss_g: 4.307
# Epoch 5 Step 625 - loss_d: 0.400, loss_g: 4.308
# Epoch 5 Step 626 - loss_d: 0.399, loss_g: 4.308
# Epoch 5 Step 627 - loss_d: 0.399, loss_g: 4.311
# Epoch 5 Step 628 - loss_d: 0.398, loss_g: 4.311
# Epoch 5 Step 629 - loss_d: 0.398, loss_g: 4.313
# Epoch 5 Step 630 - loss_d: 0.397, loss_g: 4.313
# Epoch 5 Step 631 - loss_d: 0.397, loss_g: 4.313
# Epoch 5 Step 632 - loss_d: 0.396, loss_g: 4.311
# Epoch 5 Step 633 - loss_d: 0.396, loss_g: 4.312
# Epoch 5 Step 634 - loss_d: 0.395, loss_g: 4.313
# Epoch 5 Step 635 - loss_d: 0.395, loss_g: 4.314
# Epoch 5 Step 636 - loss_d: 0.394, loss_g: 4.315
# Epoch 5 Step 637 - loss_d: 0.394, loss_g: 4.316
# Epoch 5 Step 638 - loss_d: 0.393, loss_g: 4.316
# Epoch 5 Step 639 - loss_d: 0.393, loss_g: 4.317
# Epoch 5 Step 640 - loss_d: 0.392, loss_g: 4.317
# Epoch 5 Step 641 - loss_d: 0.392, loss_g: 4.317
# Epoch 5 Step 642 - loss_d: 0.392, loss_g: 4.317
# Epoch 5 Step 643 - loss_d: 0.391, loss_g: 4.316
# Epoch 5 Step 644 - loss_d: 0.391, loss_g: 4.316
# Epoch 5 Step 645 - loss_d: 0.390, loss_g: 4.318
# Epoch 5 Step 646 - loss_d: 0.390, loss_g: 4.318
# Epoch 5 Step 647 - loss_d: 0.389, loss_g: 4.317
# Epoch 5 Step 648 - loss_d: 0.389, loss_g: 4.318
# Epoch 5 Step 649 - loss_d: 0.388, loss_g: 4.318
# Epoch 5 Step 650 - loss_d: 0.388, loss_g: 4.318
# Epoch 5 Step 651 - loss_d: 0.387, loss_g: 4.320
# Epoch 5 Step 652 - loss_d: 0.387, loss_g: 4.318
# Epoch 5 Step 653 - loss_d: 0.386, loss_g: 4.320
# Epoch 5 Step 654 - loss_d: 0.386, loss_g: 4.320
# Epoch 5 Step 655 - loss_d: 0.385, loss_g: 4.321
# Epoch 5 Step 656 - loss_d: 0.385, loss_g: 4.320
# Epoch 5 Step 657 - loss_d: 0.384, loss_g: 4.321
# Epoch 5 Step 658 - loss_d: 0.384, loss_g: 4.321
# Epoch 5 Step 659 - loss_d: 0.383, loss_g: 4.320
# Epoch 5 Step 660 - loss_d: 0.383, loss_g: 4.320
# Epoch 5 Step 661 - loss_d: 0.382, loss_g: 4.322
# Epoch 5 Step 662 - loss_d: 0.382, loss_g: 4.322
# Epoch 5 Step 663 - loss_d: 0.381, loss_g: 4.321
# Epoch 5 Step 664 - loss_d: 0.381, loss_g: 4.321
# Epoch 5 Step 665 - loss_d: 0.381, loss_g: 4.323
# Epoch 5 Step 666 - loss_d: 0.380, loss_g: 4.323
# Epoch 5 Step 667 - loss_d: 0.380, loss_g: 4.322
# Epoch 5 Step 668 - loss_d: 0.379, loss_g: 4.320
# Epoch 5 Step 669 - loss_d: 0.379, loss_g: 4.321
# Epoch 5 Step 670 - loss_d: 0.378, loss_g: 4.322
# Epoch 5 Step 671 - loss_d: 0.378, loss_g: 4.325
# Epoch 5 Step 672 - loss_d: 0.377, loss_g: 4.325
# Epoch 5 Step 673 - loss_d: 0.377, loss_g: 4.331
# Epoch 5 Step 674 - loss_d: 0.376, loss_g: 4.331
# Epoch 5 Step 675 - loss_d: 0.376, loss_g: 4.331
# Epoch 5 Step 676 - loss_d: 0.375, loss_g: 4.331
# Epoch 5 Step 677 - loss_d: 0.375, loss_g: 4.332
# Epoch 5 Step 678 - loss_d: 0.374, loss_g: 4.332
# Epoch 5 Step 679 - loss_d: 0.374, loss_g: 4.331
# Epoch 5 Step 680 - loss_d: 0.374, loss_g: 4.332
# Epoch 5 Step 681 - loss_d: 0.373, loss_g: 4.331
# Epoch 5 Step 682 - loss_d: 0.373, loss_g: 4.332
# Epoch 5 Step 683 - loss_d: 0.372, loss_g: 4.332
# Epoch 5 Step 684 - loss_d: 0.372, loss_g: 4.331
# Epoch 5 Step 685 - loss_d: 0.371, loss_g: 4.331
# Epoch 5 Step 686 - loss_d: 0.371, loss_g: 4.335
# Epoch 5 Step 687 - loss_d: 0.370, loss_g: 4.334
# Epoch 5 Step 688 - loss_d: 0.370, loss_g: 4.333
# Epoch 5 Step 689 - loss_d: 0.370, loss_g: 4.333
# Epoch 5 Step 690 - loss_d: 0.369, loss_g: 4.335
# Epoch 5 Step 691 - loss_d: 0.369, loss_g: 4.337
# Epoch 5 Step 692 - loss_d: 0.368, loss_g: 4.339
# Epoch 5 Step 693 - loss_d: 0.368, loss_g: 4.339
# Epoch 5 Step 694 - loss_d: 0.367, loss_g: 4.340
# Epoch 5 Step 695 - loss_d: 0.367, loss_g: 4.343
# Epoch 5 Step 696 - loss_d: 0.367, loss_g: 4.346
# Epoch 5 Step 697 - loss_d: 0.366, loss_g: 4.344
# Epoch 5 Step 698 - loss_d: 0.366, loss_g: 4.347
# Epoch 5 Step 699 - loss_d: 0.365, loss_g: 4.346
# Epoch 5 Step 700 - loss_d: 0.365, loss_g: 4.346
# Epoch 5 Step 701 - loss_d: 0.365, loss_g: 4.344
# Epoch 5 Step 702 - loss_d: 0.364, loss_g: 4.345
# Epoch 5 Step 703 - loss_d: 0.364, loss_g: 4.348
# Epoch 5 Step 704 - loss_d: 0.364, loss_g: 4.350
# Epoch 5 Step 705 - loss_d: 0.364, loss_g: 4.351
# Epoch 5 Step 706 - loss_d: 0.363, loss_g: 4.349
# Epoch 5 Step 707 - loss_d: 0.363, loss_g: 4.349
# Epoch 5 Step 708 - loss_d: 0.363, loss_g: 4.349
# Epoch 5 Step 709 - loss_d: 0.362, loss_g: 4.348
# Epoch 5 Step 710 - loss_d: 0.362, loss_g: 4.349
# Epoch 5 Step 711 - loss_d: 0.362, loss_g: 4.350
# Epoch 5 Step 712 - loss_d: 0.361, loss_g: 4.349
# Epoch 5 Step 713 - loss_d: 0.361, loss_g: 4.349
# Epoch 5 Step 714 - loss_d: 0.360, loss_g: 4.352
# Epoch 5 Step 715 - loss_d: 0.360, loss_g: 4.352
# Epoch 5 Step 716 - loss_d: 0.360, loss_g: 4.351
# Epoch 5 Step 717 - loss_d: 0.359, loss_g: 4.351
# Epoch 5 Step 718 - loss_d: 0.359, loss_g: 4.352
# Epoch 5 Step 719 - loss_d: 0.359, loss_g: 4.355
# Epoch 5 Step 720 - loss_d: 0.358, loss_g: 4.353
# Epoch 5 Step 721 - loss_d: 0.358, loss_g: 4.354
# Epoch 5 Step 722 - loss_d: 0.357, loss_g: 4.355
# Epoch 5 Step 723 - loss_d: 0.357, loss_g: 4.358
# Epoch 5 Step 724 - loss_d: 0.356, loss_g: 4.358
# Epoch 5 Step 725 - loss_d: 0.356, loss_g: 4.358
# Epoch 5 Step 726 - loss_d: 0.356, loss_g: 4.359
# Epoch 5 Step 727 - loss_d: 0.355, loss_g: 4.358
# Epoch 5 Step 728 - loss_d: 0.355, loss_g: 4.358
# Epoch 5 Step 729 - loss_d: 0.354, loss_g: 4.359
# Epoch 5 Step 730 - loss_d: 0.354, loss_g: 4.358
# Epoch 5 Step 731 - loss_d: 0.354, loss_g: 4.359
# Epoch 5 Step 732 - loss_d: 0.353, loss_g: 4.357
# Epoch 5 Step 733 - loss_d: 0.353, loss_g: 4.359
# Epoch 5 Step 734 - loss_d: 0.352, loss_g: 4.361
# Epoch 5 Step 735 - loss_d: 0.352, loss_g: 4.359
# Epoch 5 Step 736 - loss_d: 0.352, loss_g: 4.360
# Epoch 5 Step 737 - loss_d: 0.351, loss_g: 4.362
# Epoch 5 Step 738 - loss_d: 0.351, loss_g: 4.362
# Epoch 5 Step 739 - loss_d: 0.351, loss_g: 4.364
# Epoch 5 Step 740 - loss_d: 0.351, loss_g: 4.363
# Epoch 5 Step 741 - loss_d: 0.350, loss_g: 4.364
# Epoch 5 Step 742 - loss_d: 0.350, loss_g: 4.364
# Epoch 5 Step 743 - loss_d: 0.349, loss_g: 4.365
# Epoch 5 Step 744 - loss_d: 0.349, loss_g: 4.365
# Epoch 5 Step 745 - loss_d: 0.349, loss_g: 4.367
# Epoch 5 Step 746 - loss_d: 0.348, loss_g: 4.367
# Epoch 5 Step 747 - loss_d: 0.348, loss_g: 4.369
# Epoch 5 Step 748 - loss_d: 0.348, loss_g: 4.368
# Epoch 5 Step 749 - loss_d: 0.347, loss_g: 4.369
# Epoch 5 Step 750 - loss_d: 0.347, loss_g: 4.369
# Epoch 5 Step 751 - loss_d: 0.346, loss_g: 4.369
# Epoch 5 Step 752 - loss_d: 0.346, loss_g: 4.370
# Epoch 5 Step 753 - loss_d: 0.346, loss_g: 4.370
# Epoch 5 Step 754 - loss_d: 0.345, loss_g: 4.369
# Epoch 5 Step 755 - loss_d: 0.345, loss_g: 4.373
# Epoch 5 Step 756 - loss_d: 0.345, loss_g: 4.373
# Epoch 5 Step 757 - loss_d: 0.344, loss_g: 4.375
# Epoch 5 Step 758 - loss_d: 0.344, loss_g: 4.376
# Epoch 5 Step 759 - loss_d: 0.343, loss_g: 4.378
# Epoch 5 Step 760 - loss_d: 0.343, loss_g: 4.379
# Epoch 5 Step 761 - loss_d: 0.343, loss_g: 4.379
# Epoch 5 Step 762 - loss_d: 0.342, loss_g: 4.382
# Epoch 5 Step 763 - loss_d: 0.342, loss_g: 4.383
# Epoch 5 Step 764 - loss_d: 0.342, loss_g: 4.387
# Epoch 5 Step 765 - loss_d: 0.341, loss_g: 4.390
# Epoch 5 Step 766 - loss_d: 0.341, loss_g: 4.388
# Epoch 5 Step 767 - loss_d: 0.340, loss_g: 4.389
# Epoch 5 Step 768 - loss_d: 0.340, loss_g: 4.389
# Epoch 5 Step 769 - loss_d: 0.340, loss_g: 4.391
# Epoch 5 Step 770 - loss_d: 0.339, loss_g: 4.392
# Epoch 5 Step 771 - loss_d: 0.339, loss_g: 4.394
# Epoch 5 Step 772 - loss_d: 0.339, loss_g: 4.394
# Epoch 5 Step 773 - loss_d: 0.338, loss_g: 4.396
# Epoch 5 Step 774 - loss_d: 0.338, loss_g: 4.396
# Epoch 5 Step 775 - loss_d: 0.337, loss_g: 4.399
# Epoch 5 Step 776 - loss_d: 0.337, loss_g: 4.399
# Epoch 5 Step 777 - loss_d: 0.337, loss_g: 4.403
# Epoch 5 Step 778 - loss_d: 0.336, loss_g: 4.403
# Epoch 5 Step 779 - loss_d: 0.336, loss_g: 4.403
# Epoch 5 Step 780 - loss_d: 0.336, loss_g: 4.404
# Epoch 5 Step 781 - loss_d: 0.335, loss_g: 4.404
# Epoch 5 Step 782 - loss_d: 0.335, loss_g: 4.406
# Epoch 5 Step 783 - loss_d: 0.334, loss_g: 4.406
# Epoch 5 Step 784 - loss_d: 0.334, loss_g: 4.410
# Epoch 5 Step 785 - loss_d: 0.334, loss_g: 4.409
# Epoch 5 Step 786 - loss_d: 0.333, loss_g: 4.414
# Epoch 5 Step 787 - loss_d: 0.333, loss_g: 4.414
# Epoch 5 Step 788 - loss_d: 0.332, loss_g: 4.416
# Epoch 5 Step 789 - loss_d: 0.332, loss_g: 4.414
# Epoch 5 Step 790 - loss_d: 0.332, loss_g: 4.416
# Epoch 5 Step 791 - loss_d: 0.331, loss_g: 4.416
# Epoch 5 Step 792 - loss_d: 0.331, loss_g: 4.417
# Epoch 5 Step 793 - loss_d: 0.331, loss_g: 4.416
# Epoch 5 Step 794 - loss_d: 0.330, loss_g: 4.416
# Epoch 5 Step 795 - loss_d: 0.330, loss_g: 4.417
# Epoch 5 Step 796 - loss_d: 0.330, loss_g: 4.418
# Epoch 5 Step 797 - loss_d: 0.329, loss_g: 4.421
# Epoch 5 Step 798 - loss_d: 0.329, loss_g: 4.420
# Epoch 5 Step 799 - loss_d: 0.329, loss_g: 4.422
# Epoch 5 Step 800 - loss_d: 0.328, loss_g: 4.423
# Epoch 5 Step 801 - loss_d: 0.328, loss_g: 4.424
# Epoch 5 Step 802 - loss_d: 0.328, loss_g: 4.424
# Epoch 5 Step 803 - loss_d: 0.327, loss_g: 4.424
# Epoch 5 Step 804 - loss_d: 0.327, loss_g: 4.424
# Epoch 5 Step 805 - loss_d: 0.327, loss_g: 4.425
# Epoch 5 Step 806 - loss_d: 0.326, loss_g: 4.426
# Epoch 5 Step 807 - loss_d: 0.326, loss_g: 4.427
# Epoch 5 Step 808 - loss_d: 0.326, loss_g: 4.428
# Epoch 5 Step 809 - loss_d: 0.326, loss_g: 4.423
# Epoch 5 Step 810 - loss_d: 0.327, loss_g: 4.433
# Epoch 5 Step 811 - loss_d: 0.329, loss_g: 4.427
# Epoch 5 Step 812 - loss_d: 0.334, loss_g: 4.438
# Epoch 5 Step 813 - loss_d: 0.343, loss_g: 4.435
# Epoch 5 Step 814 - loss_d: 0.346, loss_g: 4.437
# Epoch 5 Step 815 - loss_d: 0.349, loss_g: 4.432
# Epoch 5 Step 816 - loss_d: 0.352, loss_g: 4.430
# Epoch 5 Step 817 - loss_d: 0.353, loss_g: 4.428
# Epoch 5 Step 818 - loss_d: 0.354, loss_g: 4.426
# Epoch 5 Step 819 - loss_d: 0.355, loss_g: 4.423
# Epoch 5 Step 820 - loss_d: 0.356, loss_g: 4.422
# Epoch 5 Step 821 - loss_d: 0.357, loss_g: 4.418
# Epoch 5 Step 822 - loss_d: 0.358, loss_g: 4.418
# Epoch 5 Step 823 - loss_d: 0.358, loss_g: 4.416
# Epoch 5 Step 824 - loss_d: 0.358, loss_g: 4.413
# Epoch 5 Step 825 - loss_d: 0.359, loss_g: 4.413
# Epoch 5 Step 826 - loss_d: 0.359, loss_g: 4.410
# Epoch 5 Step 827 - loss_d: 0.360, loss_g: 4.409
# Epoch 5 Step 828 - loss_d: 0.361, loss_g: 4.404
# Epoch 5 Step 829 - loss_d: 0.362, loss_g: 4.407
# Epoch 5 Step 830 - loss_d: 0.363, loss_g: 4.405
# Epoch 5 Step 831 - loss_d: 0.363, loss_g: 4.402
# Epoch 5 Step 832 - loss_d: 0.364, loss_g: 4.404
# Epoch 5 Step 833 - loss_d: 0.365, loss_g: 4.401
# Epoch 5 Step 834 - loss_d: 0.366, loss_g: 4.400
# Epoch 5 Step 835 - loss_d: 0.367, loss_g: 4.397
# Epoch 5 Step 836 - loss_d: 0.368, loss_g: 4.397
# Epoch 5 Step 837 - loss_d: 0.368, loss_g: 4.395
# Epoch 5 Step 838 - loss_d: 0.368, loss_g: 4.393
# Epoch 5 Step 839 - loss_d: 0.368, loss_g: 4.393
# Epoch 5 Step 840 - loss_d: 0.369, loss_g: 4.390
# Epoch 5 Step 841 - loss_d: 0.369, loss_g: 4.390
# Epoch 5 Step 842 - loss_d: 0.370, loss_g: 4.386
# Epoch 5 Step 843 - loss_d: 0.371, loss_g: 4.388
# Epoch 5 Step 844 - loss_d: 0.371, loss_g: 4.387
# Epoch 5 Step 845 - loss_d: 0.371, loss_g: 4.385
# Epoch 5 Step 846 - loss_d: 0.371, loss_g: 4.385
# Epoch 5 Step 847 - loss_d: 0.371, loss_g: 4.385
# Epoch 5 Step 848 - loss_d: 0.371, loss_g: 4.383
# Epoch 5 Step 849 - loss_d: 0.372, loss_g: 4.383
# Epoch 5 Step 850 - loss_d: 0.373, loss_g: 4.380
# Epoch 5 Step 851 - loss_d: 0.375, loss_g: 4.385
# Epoch 5 Step 852 - loss_d: 0.376, loss_g: 4.385
# Epoch 5 Step 853 - loss_d: 0.376, loss_g: 4.382
# Epoch 5 Step 854 - loss_d: 0.376, loss_g: 4.382
# Epoch 5 Step 855 - loss_d: 0.376, loss_g: 4.382
# Epoch 5 Step 856 - loss_d: 0.376, loss_g: 4.379
# Epoch 5 Step 857 - loss_d: 0.377, loss_g: 4.382
# Epoch 5 Step 858 - loss_d: 0.379, loss_g: 4.380
# Epoch 5 Step 859 - loss_d: 0.379, loss_g: 4.381
# Epoch 5 Step 860 - loss_d: 0.380, loss_g: 4.380
# Epoch 5 Step 861 - loss_d: 0.380, loss_g: 4.380
# Epoch 5 Step 862 - loss_d: 0.380, loss_g: 4.379
# Epoch 5 Step 863 - loss_d: 0.380, loss_g: 4.377
# Epoch 5 Step 864 - loss_d: 0.380, loss_g: 4.377
# Epoch 5 Step 865 - loss_d: 0.380, loss_g: 4.377
# Epoch 5 Step 866 - loss_d: 0.380, loss_g: 4.377
# Epoch 5 Step 867 - loss_d: 0.380, loss_g: 4.374
# Epoch 5 Step 868 - loss_d: 0.380, loss_g: 4.375
# Epoch 5 Step 869 - loss_d: 0.380, loss_g: 4.376
# Epoch 5 Step 870 - loss_d: 0.380, loss_g: 4.377
# Epoch 5 Step 871 - loss_d: 0.379, loss_g: 4.377
# Epoch 5 Step 872 - loss_d: 0.379, loss_g: 4.376
# Epoch 5 Step 873 - loss_d: 0.379, loss_g: 4.376
# Epoch 5 Step 874 - loss_d: 0.379, loss_g: 4.376
# Epoch 5 Step 875 - loss_d: 0.379, loss_g: 4.378
# Epoch 5 Step 876 - loss_d: 0.380, loss_g: 4.376
# Epoch 5 Step 877 - loss_d: 0.380, loss_g: 4.376
# Epoch 5 Step 878 - loss_d: 0.380, loss_g: 4.380
# Epoch 5 Step 879 - loss_d: 0.383, loss_g: 4.376
# Epoch 5 Step 880 - loss_d: 0.389, loss_g: 4.377
# Epoch 5 Step 881 - loss_d: 0.389, loss_g: 4.379
# Epoch 5 Step 882 - loss_d: 0.390, loss_g: 4.376
# Epoch 5 Step 883 - loss_d: 0.391, loss_g: 4.374
# Epoch 5 Step 884 - loss_d: 0.391, loss_g: 4.374
# Epoch 5 Step 885 - loss_d: 0.392, loss_g: 4.372
# Epoch 5 Step 886 - loss_d: 0.392, loss_g: 4.370
# Epoch 5 Step 887 - loss_d: 0.393, loss_g: 4.369
# Epoch 5 Step 888 - loss_d: 0.393, loss_g: 4.368
# Epoch 5 Step 889 - loss_d: 0.393, loss_g: 4.366
# Epoch 5 Step 890 - loss_d: 0.393, loss_g: 4.366
# Epoch 5 Step 891 - loss_d: 0.393, loss_g: 4.365
# Epoch 5 Step 892 - loss_d: 0.394, loss_g: 4.364
# Epoch 5 Step 893 - loss_d: 0.394, loss_g: 4.363
# Epoch 5 Step 894 - loss_d: 0.394, loss_g: 4.362
# Epoch 5 Step 895 - loss_d: 0.393, loss_g: 4.361
# Epoch 5 Step 896 - loss_d: 0.393, loss_g: 4.362
# Epoch 5 Step 897 - loss_d: 0.393, loss_g: 4.361
# Epoch 5 Step 898 - loss_d: 0.393, loss_g: 4.359
# Epoch 5 Step 899 - loss_d: 0.393, loss_g: 4.358
# Epoch 5 Step 900 - loss_d: 0.393, loss_g: 4.357
# Epoch 5 Step 901 - loss_d: 0.393, loss_g: 4.356
# Epoch 5 Step 902 - loss_d: 0.392, loss_g: 4.357
# Epoch 5 Step 903 - loss_d: 0.392, loss_g: 4.357
# Epoch 5 Step 904 - loss_d: 0.392, loss_g: 4.354
# Epoch 5 Step 905 - loss_d: 0.392, loss_g: 4.356
# Epoch 5 Step 906 - loss_d: 0.393, loss_g: 4.355
# Epoch 5 Step 907 - loss_d: 0.393, loss_g: 4.354
# Epoch 5 Step 908 - loss_d: 0.393, loss_g: 4.351
# Epoch 5 Step 909 - loss_d: 0.393, loss_g: 4.353
# Epoch 5 Step 910 - loss_d: 0.394, loss_g: 4.349
# Epoch 5 Step 911 - loss_d: 0.395, loss_g: 4.352
# Epoch 5 Step 912 - loss_d: 0.395, loss_g: 4.353
# Epoch 5 Step 913 - loss_d: 0.395, loss_g: 4.353
# Epoch 5 Step 914 - loss_d: 0.395, loss_g: 4.352
# Epoch 5 Step 915 - loss_d: 0.395, loss_g: 4.354
# Epoch 5 Step 916 - loss_d: 0.395, loss_g: 4.353
# Epoch 5 Step 917 - loss_d: 0.394, loss_g: 4.353
# Epoch 5 Step 918 - loss_d: 0.394, loss_g: 4.353
# Epoch 5 Step 919 - loss_d: 0.394, loss_g: 4.352
# Epoch 5 Step 920 - loss_d: 0.394, loss_g: 4.350
# Epoch 5 Step 921 - loss_d: 0.394, loss_g: 4.351
# Epoch 5 Step 922 - loss_d: 0.394, loss_g: 4.350
# Epoch 5 Step 923 - loss_d: 0.394, loss_g: 4.348
# Epoch 5 Step 924 - loss_d: 0.393, loss_g: 4.348
# Epoch 5 Step 925 - loss_d: 0.393, loss_g: 4.348
# Epoch 5 Step 926 - loss_d: 0.393, loss_g: 4.350
# Epoch 5 Step 927 - loss_d: 0.393, loss_g: 4.349
# Epoch 5 Step 928 - loss_d: 0.392, loss_g: 4.349
# Epoch 5 Step 929 - loss_d: 0.392, loss_g: 4.349
# Epoch 5 Step 930 - loss_d: 0.392, loss_g: 4.349
# Epoch 5 Step 931 - loss_d: 0.392, loss_g: 4.349
# Epoch 5 Step 932 - loss_d: 0.391, loss_g: 4.349
# Epoch 5 Step 933 - loss_d: 0.391, loss_g: 4.350
# Epoch 5 Step 934 - loss_d: 0.391, loss_g: 4.352
# Epoch 5 Step 935 - loss_d: 0.391, loss_g: 4.351
# Epoch 5 Step 936 - loss_d: 0.391, loss_g: 4.350
# Epoch 5 Step 937 - loss_d: 0.390, loss_g: 4.350
# Epoch 5 Step 938 - loss_d: 0.390, loss_g: 4.348
# Epoch 5 - loss_d: 0.390, loss_g: 4.348

# %%
plot_output()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
